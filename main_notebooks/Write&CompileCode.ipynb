# %% [markdown]
# In order to ensure accuracy of position-steepness points, high precision calculations using boost/MPFR in C++ are best. What we do is to do the calculations in C++, and then call the code from Python using pybind11. In order to make writing the C++ code more easily, the code in writescripts.py is used. This notebook contains the necessary code to write the cpp files and compile them so that then the code is read into Python as if it were any other python module.
#
# Requirements:
#
# Code to solve polynomials with high accuracy: https://github.com/kmnam/polynomials.git (commit af5a8318a6d637680033858a9b902c6d02eff613)
#
#
# writescripts.py file and the files it depends on, in GeneRegulatoryFunctions repository: https://github.com/rosamc/GeneRegulatoryFunctions.git
#
#
# This also writes mathematica code to doublecheck the results of the boundaries in mathematica. These are the .wl files. In some cases, I increased a bit the tolerance, from 0.005 to 0.0075 or so, when running the doublechecks, so that I would only see notable differences in position and/or steepness.

# %%
import numpy as np
import sys, os, re
import matplotlib.pyplot as plt

# %%
path_to_eigen="/Users/rosamartinezcorral/Documents/eigenlibrary/eigen-eigen-323c052e1731/" #for backward compatibility, no longer required
path_to_polynomials="\"/Users/rosamartinezcorral/Dropbox (HMS)/backup_crg/repos/shared_fromothers/polynomials_multiprecision/polynomials/include/polynomial/\""
path_to_utilsGRF="\"/Users/rosamartinezcorral/Dropbox (HMS)/backup_crg/repos/shared/utilsGRF\"" #GeneRegulatoryFunctions repo
path_to_utilsGRF_="/Users/rosamartinezcorral/Dropbox (HMS)/backup_crg/repos/shared/utilsGRF" #GeneRegulatoryFunctions repo
sys.path.append(path_to_utilsGRF_)

import writescripts

# %%
folder='../bin'

# %% [markdown]
# # Average binding model

# %%
obj=writescripts.PrepareFilesEqbindingmodels(varGRF="x",concvars=["x"],N=4,strategy="av")
obj.get_rhos_and_GRFs()

fname=os.path.join(folder,'N4av.cpp')
funcname='N4av'
obj.write_pybind_interface(fname=fname, funcname=funcname)
obj.write_checkfile_mathematica_singlevar(fname=fname.replace('.cpp','.wl'),min0=True, max1=True)
obj.write_checksingleparset_mathematica_singlevar(fname=fname.replace('.cpp','.nb'),min0=True, max1=True)

path_1,file=os.path.split(fname)
objectnamemac=os.path.join(path_1,file.replace('.cpp','')) 

compilestringmac="c++ -O2 -DNDEBUG -Wall -shared -std=c++11  -fPIC -undefined dynamic_lookup -I %s -lmpfr -lmpc -I %s  `python3 -m pybind11 --includes` %s -o %s`python3-config --extension-suffix`"%(path_to_polynomials,path_to_utilsGRF,fname,objectnamemac)

compilestring=compilestringmac
print(compilestring)

# !$compilestring
# Out:
# ['K1', 'K2', 'K3', 'K4', 'w12', 'w13', 'w14', 'w23', 'w24', 'w34', 'w123', 'w124', 'w134', 'w234', 'w1234']
# parlist is ['K1', 'K2', 'K3', 'K4', 'w12', 'w13', 'w14', 'w23', 'w24', 'w34', 'w123', 'w124', 'w134', 'w234', 'w1234']
# GRF numerator:(1.0/4)*(rho2)+(1.0/4)*(rho3)+(1.0/4)*(rho4)+(1.0/4)*(rho5)+(2.0/4)*(rho6)+(2.0/4)*(rho7)+(2.0/4)*(rho8)+(2.0/4)*(rho9)+(2.0/4)*(rho10)+(2.0/4)*(rho11)+(3.0/4)*(rho12)+(3.0/4)*(rho13)+(3.0/4)*(rho14)+(3.0/4)*(rho15)+(4.0/4)*(rho16)
# GRF denominator:1*(rho1+rho2+rho3+rho4+rho5+rho6+rho7+rho8+rho9+rho10+rho11+rho12+rho13+rho14+rho15+rho16)
# 0
# 1
# writing mathematica file. max1 set to True
# K1_,K2_,K3_,K4_,w12_,w13_,w14_,w23_,w24_,w34_,w123_,w124_,w134_,w234_,w1234_,
# writing mathematica file. max1 set to True
# K1_,K2_,K3_,K4_,w12_,w13_,w14_,w23_,w24_,w34_,w123_,w124_,w134_,w234_,w1234_,
# c++ -O2 -DNDEBUG -Wall -shared -std=c++11  -fPIC -undefined dynamic_lookup -I "/Users/rosamartinezcorral/Dropbox (HMS)/work2/shared_fromothers/polynomials_multiprecision/polynomials/include/polynomial/" -lmpfr -lmpc -I "/Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF"  `python3 -m pybind11 --includes` ../bin/N4av.cpp -o ../bin/N4av`python3-config --extension-suffix`
# In file included from ../bin/N4av.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:667:17: warning: unused variable 'i2' [-Wunused-variable]
#     long double i2;
#                 ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:666:17: warning: unused variable 'i1' [-Wunused-variable]
#     long double i1;
#                 ^
# ../bin/N4av.cpp:24:13: warning: unused variable 'varsar' [-Wunused-variable]
#     double *varsar=(double *) varsarbuf.ptr;
#             ^
# In file included from ../bin/N4av.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:512:11: warning: unused variable 'mincritpoint' [-Wunused-variable]
#         T mincritpoint;
#           ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/N4av.cpp:126:88: note: in instantiation of member function 'GRFCalculations<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &N4av_GRFCalculations<long double,mpc_50,polytype_50,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                        ^
# In file included from ../bin/N4av.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:513:22: warning: unused variable 'thirdderx0' [-Wunused-variable]
#         T thirdderx, thirdderx0;
#                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:217:83: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type nnum, nden, degreenum, degreeden, degreesum, i, j;
#                                                                                   ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:403:5: note: in instantiation of function template specialization 'get_fraction_derivative_coeffs<long double>' requested here
#     get_fraction_derivative_coeffs<T>(num,den,derivativenum,derivativeden);
#     ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/N4av.cpp:126:88: note: in instantiation of member function 'GRFCalculations<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &N4av_GRFCalculations<long double,mpc_50,polytype_50,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                        ^
# In file included from ../bin/N4av.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:665:38: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type i, j, nnum, nden;
#                                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:169:20: note: in instantiation of function template specialization 'compute_monotonic<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#             result=compute_monotonic<T,Tpolyc,polytype,thresholdtype>(num,den,thresholdimag); //return {-1} if derivative is 0, {-2} if no roots for the derivative of the GRF, -3 for each root out of the 10^-15,10^15 range, and the roots otherwise
#                    ^
# ../bin/N4av.cpp:128:95: note: in instantiation of member function 'GRFCalculations<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfacemonotonic' requested here
#     .def("interfacemonotonic", &N4av_GRFCalculations<long double,mpc_50,polytype_50,mpfr_15>::interfacemonotonic, py::arg("thresholdimag")=1e-15)
#                                                                                               ^
# In file included from ../bin/N4av.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:217:83: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type nnum, nden, degreenum, degreeden, degreesum, i, j;
#                                                                                   ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:403:5: note: in instantiation of function template specialization 'get_fraction_derivative_coeffs<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#     get_fraction_derivative_coeffs<T>(num,den,derivativenum,derivativeden);
#     ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/N4av.cpp:137:84: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &N4av_GRFCalculations<mpfr_50,mpc_50,polytype_50,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                    ^
# In file included from ../bin/N4av.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:665:38: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type i, j, nnum, nden;
#                                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:169:20: note: in instantiation of function template specialization 'compute_monotonic<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#             result=compute_monotonic<T,Tpolyc,polytype,thresholdtype>(num,den,thresholdimag); //return {-1} if derivative is 0, {-2} if no roots for the derivative of the GRF, -3 for each root out of the 10^-15,10^15 range, and the roots otherwise
#                    ^
# ../bin/N4av.cpp:139:91: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfacemonotonic' requested here
#     .def("interfacemonotonic", &N4av_GRFCalculations<mpfr_50,mpc_50,polytype_50,mpfr_15>::interfacemonotonic, py::arg("thresholdimag")=1e-15)
#                                                                                           ^
# In file included from ../bin/N4av.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:217:83: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type nnum, nden, degreenum, degreeden, degreesum, i, j;
#                                                                                   ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:403:5: note: in instantiation of function template specialization 'get_fraction_derivative_coeffs<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#     get_fraction_derivative_coeffs<T>(num,den,derivativenum,derivativeden);
#     ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/N4av.cpp:148:87: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &N4av_GRFCalculations<mpfr_100,mpc_100,polytype_100,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                       ^
# In file included from ../bin/N4av.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:665:38: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type i, j, nnum, nden;
#                                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:169:20: note: in instantiation of function template specialization 'compute_monotonic<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#             result=compute_monotonic<T,Tpolyc,polytype,thresholdtype>(num,den,thresholdimag); //return {-1} if derivative is 0, {-2} if no roots for the derivative of the GRF, -3 for each root out of the 10^-15,10^15 range, and the roots otherwise
#                    ^
# ../bin/N4av.cpp:150:94: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfacemonotonic' requested here
#     .def("interfacemonotonic", &N4av_GRFCalculations<mpfr_100,mpc_100,polytype_100,mpfr_15>::interfacemonotonic, py::arg("thresholdimag")=1e-15)
#                                                                                              ^
# In file included from ../bin/N4av.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:10:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared_fromothers/polynomials_multiprecision/polynomials/include/polynomial/polynomial.hpp:1122:52: warning: unused typedef 'RTM' [-Wunused-local-typedef]
#             typedef number<mpfr_float_backend<M> > RTM;
#                                                    ^
# 12 warnings generated.

# %%
obj=writescripts.PrepareFilesEqbindingmodels(varGRF="x",concvars=["x"],N=6,strategy="av")
obj.get_rhos_and_GRFs()

fname=os.path.join(folder,'N6av.cpp')
funcname='N6av'
obj.write_pybind_interface(fname=fname, funcname=funcname)
obj.write_checkfile_mathematica_singlevar(fname=fname.replace('.cpp','.wl'),min0=True, max1=True)
obj.write_checksingleparset_mathematica_singlevar(fname=fname.replace('.cpp','.nb'),min0=True, max1=True)

path_1,file=os.path.split(fname)
objectnamemac=os.path.join(path_1,file.replace('.cpp','')) 

compilestringmac="c++ -O2 -DNDEBUG -Wall -shared -std=c++11  -fPIC -undefined dynamic_lookup -I %s -lmpfr -lmpc -I %s  `python3 -m pybind11 --includes` %s -o %s`python3-config --extension-suffix`"%(path_to_polynomials,path_to_utilsGRF,fname,objectnamemac)

compilestring=compilestringmac
print(compilestring)

# !$compilestring
# Out:
# ['K1', 'K2', 'K3', 'K4', 'K5', 'K6', 'w12', 'w13', 'w14', 'w15', 'w16', 'w23', 'w24', 'w25', 'w26', 'w34', 'w35', 'w36', 'w45', 'w46', 'w56', 'w123', 'w124', 'w125', 'w126', 'w134', 'w135', 'w136', 'w145', 'w146', 'w156', 'w234', 'w235', 'w236', 'w245', 'w246', 'w256', 'w345', 'w346', 'w356', 'w456', 'w1234', 'w1235', 'w1236', 'w1245', 'w1246', 'w1256', 'w1345', 'w1346', 'w1356', 'w1456', 'w2345', 'w2346', 'w2356', 'w2456', 'w3456', 'w12345', 'w12346', 'w12356', 'w12456', 'w13456', 'w23456', 'w123456']
# parlist is ['K1', 'K2', 'K3', 'K4', 'K5', 'K6', 'w12', 'w13', 'w14', 'w15', 'w16', 'w23', 'w24', 'w25', 'w26', 'w34', 'w35', 'w36', 'w45', 'w46', 'w56', 'w123', 'w124', 'w125', 'w126', 'w134', 'w135', 'w136', 'w145', 'w146', 'w156', 'w234', 'w235', 'w236', 'w245', 'w246', 'w256', 'w345', 'w346', 'w356', 'w456', 'w1234', 'w1235', 'w1236', 'w1245', 'w1246', 'w1256', 'w1345', 'w1346', 'w1356', 'w1456', 'w2345', 'w2346', 'w2356', 'w2456', 'w3456', 'w12345', 'w12346', 'w12356', 'w12456', 'w13456', 'w23456', 'w123456']
# GRF numerator:(1.0/6)*(rho2)+(1.0/6)*(rho3)+(1.0/6)*(rho4)+(1.0/6)*(rho5)+(1.0/6)*(rho6)+(1.0/6)*(rho7)+(2.0/6)*(rho8)+(2.0/6)*(rho9)+(2.0/6)*(rho10)+(2.0/6)*(rho11)+(2.0/6)*(rho12)+(2.0/6)*(rho13)+(2.0/6)*(rho14)+(2.0/6)*(rho15)+(2.0/6)*(rho16)+(2.0/6)*(rho17)+(2.0/6)*(rho18)+(2.0/6)*(rho19)+(2.0/6)*(rho20)+(2.0/6)*(rho21)+(2.0/6)*(rho22)+(3.0/6)*(rho23)+(3.0/6)*(rho24)+(3.0/6)*(rho25)+(3.0/6)*(rho26)+(3.0/6)*(rho27)+(3.0/6)*(rho28)+(3.0/6)*(rho29)+(3.0/6)*(rho30)+(3.0/6)*(rho31)+(3.0/6)*(rho32)+(3.0/6)*(rho33)+(3.0/6)*(rho34)+(3.0/6)*(rho35)+(3.0/6)*(rho36)+(3.0/6)*(rho37)+(3.0/6)*(rho38)+(3.0/6)*(rho39)+(3.0/6)*(rho40)+(3.0/6)*(rho41)+(3.0/6)*(rho42)+(4.0/6)*(rho43)+(4.0/6)*(rho44)+(4.0/6)*(rho45)+(4.0/6)*(rho46)+(4.0/6)*(rho47)+(4.0/6)*(rho48)+(4.0/6)*(rho49)+(4.0/6)*(rho50)+(4.0/6)*(rho51)+(4.0/6)*(rho52)+(4.0/6)*(rho53)+(4.0/6)*(rho54)+(4.0/6)*(rho55)+(4.0/6)*(rho56)+(4.0/6)*(rho57)+(5.0/6)*(rho58)+(5.0/6)*(rho59)+(5.0/6)*(rho60)+(5.0/6)*(rho61)+(5.0/6)*(rho62)+(5.0/6)*(rho63)+(6.0/6)*(rho64)
# GRF denominator:1*()
# 0
# 1
# writing mathematica file. max1 set to True
# K1_,K2_,K3_,K4_,K5_,K6_,w12_,w13_,w14_,w15_,w16_,w23_,w24_,w25_,w26_,w34_,w35_,w36_,w45_,w46_,w56_,w123_,w124_,w125_,w126_,w134_,w135_,w136_,w145_,w146_,w156_,w234_,w235_,w236_,w245_,w246_,w256_,w345_,w346_,w356_,w456_,w1234_,w1235_,w1236_,w1245_,w1246_,w1256_,w1345_,w1346_,w1356_,w1456_,w2345_,w2346_,w2356_,w2456_,w3456_,w12345_,w12346_,w12356_,w12456_,w13456_,w23456_,w123456_,
# writing mathematica file. max1 set to True
# K1_,K2_,K3_,K4_,K5_,K6_,w12_,w13_,w14_,w15_,w16_,w23_,w24_,w25_,w26_,w34_,w35_,w36_,w45_,w46_,w56_,w123_,w124_,w125_,w126_,w134_,w135_,w136_,w145_,w146_,w156_,w234_,w235_,w236_,w245_,w246_,w256_,w345_,w346_,w356_,w456_,w1234_,w1235_,w1236_,w1245_,w1246_,w1256_,w1345_,w1346_,w1356_,w1456_,w2345_,w2346_,w2356_,w2456_,w3456_,w12345_,w12346_,w12356_,w12456_,w13456_,w23456_,w123456_,
# c++ -O2 -DNDEBUG -Wall -shared -std=c++11  -fPIC -undefined dynamic_lookup -I "/Users/rosamartinezcorral/Dropbox (HMS)/work2/shared_fromothers/polynomials_multiprecision/polynomials/include/polynomial/" -lmpfr -lmpc -I "/Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF"  `python3 -m pybind11 --includes` ../bin/N6av.cpp -o ../bin/N6av`python3-config --extension-suffix`
# In file included from ../bin/N6av.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:667:17: warning: unused variable 'i2' [-Wunused-variable]
#     long double i2;
#                 ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:666:17: warning: unused variable 'i1' [-Wunused-variable]
#     long double i1;
#                 ^
# ../bin/N6av.cpp:72:13: warning: unused variable 'varsar' [-Wunused-variable]
#     double *varsar=(double *) varsarbuf.ptr;
#             ^
# In file included from ../bin/N6av.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:512:11: warning: unused variable 'mincritpoint' [-Wunused-variable]
#         T mincritpoint;
#           ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/N6av.cpp:322:88: note: in instantiation of member function 'GRFCalculations<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &N6av_GRFCalculations<long double,mpc_50,polytype_50,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                        ^
# In file included from ../bin/N6av.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:513:22: warning: unused variable 'thirdderx0' [-Wunused-variable]
#         T thirdderx, thirdderx0;
#                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:217:83: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type nnum, nden, degreenum, degreeden, degreesum, i, j;
#                                                                                   ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:403:5: note: in instantiation of function template specialization 'get_fraction_derivative_coeffs<long double>' requested here
#     get_fraction_derivative_coeffs<T>(num,den,derivativenum,derivativeden);
#     ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/N6av.cpp:322:88: note: in instantiation of member function 'GRFCalculations<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &N6av_GRFCalculations<long double,mpc_50,polytype_50,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                        ^
# In file included from ../bin/N6av.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:665:38: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type i, j, nnum, nden;
#                                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:169:20: note: in instantiation of function template specialization 'compute_monotonic<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#             result=compute_monotonic<T,Tpolyc,polytype,thresholdtype>(num,den,thresholdimag); //return {-1} if derivative is 0, {-2} if no roots for the derivative of the GRF, -3 for each root out of the 10^-15,10^15 range, and the roots otherwise
#                    ^
# ../bin/N6av.cpp:324:95: note: in instantiation of member function 'GRFCalculations<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfacemonotonic' requested here
#     .def("interfacemonotonic", &N6av_GRFCalculations<long double,mpc_50,polytype_50,mpfr_15>::interfacemonotonic, py::arg("thresholdimag")=1e-15)
#                                                                                               ^
# In file included from ../bin/N6av.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:217:83: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type nnum, nden, degreenum, degreeden, degreesum, i, j;
#                                                                                   ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:403:5: note: in instantiation of function template specialization 'get_fraction_derivative_coeffs<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#     get_fraction_derivative_coeffs<T>(num,den,derivativenum,derivativeden);
#     ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/N6av.cpp:333:84: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &N6av_GRFCalculations<mpfr_50,mpc_50,polytype_50,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                    ^
# In file included from ../bin/N6av.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:665:38: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type i, j, nnum, nden;
#                                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:169:20: note: in instantiation of function template specialization 'compute_monotonic<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#             result=compute_monotonic<T,Tpolyc,polytype,thresholdtype>(num,den,thresholdimag); //return {-1} if derivative is 0, {-2} if no roots for the derivative of the GRF, -3 for each root out of the 10^-15,10^15 range, and the roots otherwise
#                    ^
# ../bin/N6av.cpp:335:91: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfacemonotonic' requested here
#     .def("interfacemonotonic", &N6av_GRFCalculations<mpfr_50,mpc_50,polytype_50,mpfr_15>::interfacemonotonic, py::arg("thresholdimag")=1e-15)
#                                                                                           ^
# In file included from ../bin/N6av.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:217:83: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type nnum, nden, degreenum, degreeden, degreesum, i, j;
#                                                                                   ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:403:5: note: in instantiation of function template specialization 'get_fraction_derivative_coeffs<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#     get_fraction_derivative_coeffs<T>(num,den,derivativenum,derivativeden);
#     ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/N6av.cpp:344:87: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &N6av_GRFCalculations<mpfr_100,mpc_100,polytype_100,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                       ^
# In file included from ../bin/N6av.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:665:38: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type i, j, nnum, nden;
#                                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:169:20: note: in instantiation of function template specialization 'compute_monotonic<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#             result=compute_monotonic<T,Tpolyc,polytype,thresholdtype>(num,den,thresholdimag); //return {-1} if derivative is 0, {-2} if no roots for the derivative of the GRF, -3 for each root out of the 10^-15,10^15 range, and the roots otherwise
#                    ^
# ../bin/N6av.cpp:346:94: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfacemonotonic' requested here
#     .def("interfacemonotonic", &N6av_GRFCalculations<mpfr_100,mpc_100,polytype_100,mpfr_15>::interfacemonotonic, py::arg("thresholdimag")=1e-15)
#                                                                                              ^
# In file included from ../bin/N6av.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:10:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared_fromothers/polynomials_multiprecision/polynomials/include/polynomial/polynomial.hpp:1122:52: warning: unused typedef 'RTM' [-Wunused-local-typedef]
#             typedef number<mpfr_float_backend<M> > RTM;
#                                                    ^
# 12 warnings generated.

# %% [markdown]
# # Universal model

# %%
#generate code with the name but as if it were av (simple code), then manually modify GRF and parameters both in cpp and mathematica
#commenting out writing functions to avoid rewritting

obj=writescripts.PrepareFilesEqbindingmodels(varGRF="x",concvars=["x"],N=2,strategy="av")
obj.get_rhos_and_GRFs()

fname=os.path.join(folder,'N4univ.cpp')
funcname='N4univ'
#obj.write_pybind_interface(fname=fname, funcname=funcname)
#obj.write_checkfile_mathematica_singlevar(fname=fname.replace('.cpp','.wl'),min0=False, max1=False)
#obj.write_checksingleparset_mathematica_singlevar(fname=fname.replace('.cpp','.nb'),min0=False, max1=False)
# Out:
# ['K1', 'K2', 'w12']
# parlist is ['K1', 'K2', 'w12']
# GRF numerator:(1.0/2)*(rho2)+(1.0/2)*(rho3)+(2.0/2)*(rho4)
# GRF denominator:1*(rho1+rho2+rho3+rho4)
# 0
# 1

# %%
path_1,file=os.path.split(fname)
objectnamemac=os.path.join(path_1,file.replace('.cpp','')) 

compilestringmac="c++ -O2 -DNDEBUG -Wall -shared -std=c++11  -fPIC -undefined dynamic_lookup -I %s -lmpfr -lmpc -I %s  `python3 -m pybind11 --includes` %s -o %s`python3-config --extension-suffix`"%(path_to_polynomials,path_to_utilsGRF,fname,objectnamemac)

compilestring=compilestringmac
print(compilestring)

# !$compilestring
# Out:
# c++ -O2 -DNDEBUG -Wall -shared -std=c++11  -fPIC -undefined dynamic_lookup -I "/Users/rosamartinezcorral/Dropbox (HMS)/backup_crg/repos/shared_fromothers/polynomials_multiprecision/polynomials/include/polynomial/" -lmpfr -lmpc -I "/Users/rosamartinezcorral/Dropbox (HMS)/backup_crg/repos/shared/utilsGRF"  `python3 -m pybind11 --includes` ../bin/N4univ.cpp -o ../bin/N4univ`python3-config --extension-suffix`
# In file included from ../bin/N4univ.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/backup_crg/repos/shared/utilsGRF/commonincludes.hpp:1:
# In file included from /usr/local/include/boost/multiprecision/mpfr.hpp:9:
# /usr/local/include/boost/multiprecision/detail/standalone_config.hpp:36:7: warning: "The minimum language standard to use Boost.Math will be C++14 starting in July 2023 (Boost 1.82 release)" [-W#warnings]
#  #    warning "The minimum language standard to use Boost.Math will be C++14 starting in July 2023 (Boost 1.82 release)"
#       ^
# In file included from ../bin/N4univ.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/backup_crg/repos/shared/utilsGRF/commonincludes.hpp:1:
# In file included from /usr/local/include/boost/multiprecision/mpfr.hpp:10:
# In file included from /usr/local/include/boost/multiprecision/number.hpp:12:
# In file included from /usr/local/include/boost/multiprecision/detail/generic_interconvert.hpp:12:
# In file included from /usr/local/include/boost/multiprecision/detail/default_ops.hpp:15:
# In file included from /usr/local/include/boost/multiprecision/detail/fpclassify.hpp:13:
# In file included from /usr/local/include/boost/multiprecision/detail/float128_functions.hpp:15:
# In file included from /usr/local/include/boost/cstdfloat.hpp:18:
# In file included from /usr/local/include/boost/math/cstdfloat/cstdfloat_types.hpp:17:
# /usr/local/include/boost/math/tools/config.hpp:23:6: warning: "The minimum language standard to use Boost.Math will be C++14 starting in July 2023 (Boost 1.82 release)" [-W#warnings]
# #    warning "The minimum language standard to use Boost.Math will be C++14 starting in July 2023 (Boost 1.82 release)"
#      ^
# In file included from ../bin/N4univ.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/backup_crg/repos/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/backup_crg/repos/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/backup_crg/repos/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:667:17: warning: unused variable 'i2' [-Wunused-variable]
#     long double i2;
#                 ^
# /Users/rosamartinezcorral/Dropbox (HMS)/backup_crg/repos/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:666:17: warning: unused variable 'i1' [-Wunused-variable]
#     long double i1;
#                 ^
# ../bin/N4univ.cpp:26:13: warning: unused variable 'pars' [-Wunused-variable]
#     double *pars=(double *) parsarbuf.ptr;
#             ^
# In file included from ../bin/N4univ.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/backup_crg/repos/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/backup_crg/repos/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/backup_crg/repos/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:512:11: warning: unused variable 'mincritpoint' [-Wunused-variable]
#         T mincritpoint;
#           ^
# /Users/rosamartinezcorral/Dropbox (HMS)/backup_crg/repos/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/N4univ.cpp:62:90: note: in instantiation of member function 'GRFCalculations<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &N4univ_GRFCalculations<long double,mpc_50,polytype_50,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                          ^
# In file included from ../bin/N4univ.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/backup_crg/repos/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/backup_crg/repos/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/backup_crg/repos/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:513:22: warning: unused variable 'thirdderx0' [-Wunused-variable]
#         T thirdderx, thirdderx0;
#                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/backup_crg/repos/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:217:83: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type nnum, nden, degreenum, degreeden, degreesum, i, j;
#                                                                                   ^
# /Users/rosamartinezcorral/Dropbox (HMS)/backup_crg/repos/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:403:5: note: in instantiation of function template specialization 'get_fraction_derivative_coeffs<long double>' requested here
#     get_fraction_derivative_coeffs<T>(num,den,derivativenum,derivativeden);
#     ^
# /Users/rosamartinezcorral/Dropbox (HMS)/backup_crg/repos/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/N4univ.cpp:62:90: note: in instantiation of member function 'GRFCalculations<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &N4univ_GRFCalculations<long double,mpc_50,polytype_50,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                          ^
# In file included from ../bin/N4univ.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/backup_crg/repos/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/backup_crg/repos/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/backup_crg/repos/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:665:38: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type i, j, nnum, nden;
#                                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/backup_crg/repos/shared/utilsGRF/GRFCalculations.hpp:169:20: note: in instantiation of function template specialization 'compute_monotonic<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#             result=compute_monotonic<T,Tpolyc,polytype,thresholdtype>(num,den,thresholdimag); //return {-1} if derivative is 0, {-2} if no roots for the derivative of the GRF, -3 for each root out of the 10^-15,10^15 range, and the roots otherwise
#                    ^
# ../bin/N4univ.cpp:64:97: note: in instantiation of member function 'GRFCalculations<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfacemonotonic' requested here
#     .def("interfacemonotonic", &N4univ_GRFCalculations<long double,mpc_50,polytype_50,mpfr_15>::interfacemonotonic, py::arg("thresholdimag")=1e-15)
#                                                                                                 ^
# In file included from ../bin/N4univ.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/backup_crg/repos/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/backup_crg/repos/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/backup_crg/repos/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:217:83: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type nnum, nden, degreenum, degreeden, degreesum, i, j;
#                                                                                   ^
# /Users/rosamartinezcorral/Dropbox (HMS)/backup_crg/repos/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:403:5: note: in instantiation of function template specialization 'get_fraction_derivative_coeffs<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#     get_fraction_derivative_coeffs<T>(num,den,derivativenum,derivativeden);
#     ^
# /Users/rosamartinezcorral/Dropbox (HMS)/backup_crg/repos/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/N4univ.cpp:73:86: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &N4univ_GRFCalculations<mpfr_50,mpc_50,polytype_50,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                      ^
# In file included from ../bin/N4univ.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/backup_crg/repos/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/backup_crg/repos/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/backup_crg/repos/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:665:38: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type i, j, nnum, nden;
#                                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/backup_crg/repos/shared/utilsGRF/GRFCalculations.hpp:169:20: note: in instantiation of function template specialization 'compute_monotonic<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#             result=compute_monotonic<T,Tpolyc,polytype,thresholdtype>(num,den,thresholdimag); //return {-1} if derivative is 0, {-2} if no roots for the derivative of the GRF, -3 for each root out of the 10^-15,10^15 range, and the roots otherwise
#                    ^
# ../bin/N4univ.cpp:75:93: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfacemonotonic' requested here
#     .def("interfacemonotonic", &N4univ_GRFCalculations<mpfr_50,mpc_50,polytype_50,mpfr_15>::interfacemonotonic, py::arg("thresholdimag")=1e-15)
#                                                                                             ^
# In file included from ../bin/N4univ.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/backup_crg/repos/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/backup_crg/repos/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/backup_crg/repos/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:217:83: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type nnum, nden, degreenum, degreeden, degreesum, i, j;
#                                                                                   ^
# /Users/rosamartinezcorral/Dropbox (HMS)/backup_crg/repos/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:403:5: note: in instantiation of function template specialization 'get_fraction_derivative_coeffs<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#     get_fraction_derivative_coeffs<T>(num,den,derivativenum,derivativeden);
#     ^
# /Users/rosamartinezcorral/Dropbox (HMS)/backup_crg/repos/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/N4univ.cpp:84:89: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &N4univ_GRFCalculations<mpfr_100,mpc_100,polytype_100,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                         ^
# In file included from ../bin/N4univ.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/backup_crg/repos/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/backup_crg/repos/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/backup_crg/repos/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:665:38: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type i, j, nnum, nden;
#                                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/backup_crg/repos/shared/utilsGRF/GRFCalculations.hpp:169:20: note: in instantiation of function template specialization 'compute_monotonic<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#             result=compute_monotonic<T,Tpolyc,polytype,thresholdtype>(num,den,thresholdimag); //return {-1} if derivative is 0, {-2} if no roots for the derivative of the GRF, -3 for each root out of the 10^-15,10^15 range, and the roots otherwise
#                    ^
# ../bin/N4univ.cpp:86:96: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfacemonotonic' requested here
#     .def("interfacemonotonic", &N4univ_GRFCalculations<mpfr_100,mpc_100,polytype_100,mpfr_15>::interfacemonotonic, py::arg("thresholdimag")=1e-15)
#                                                                                                ^
# In file included from ../bin/N4univ.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/backup_crg/repos/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/backup_crg/repos/shared/utilsGRF/GRFCalculations.hpp:10:
# /Users/rosamartinezcorral/Dropbox (HMS)/backup_crg/repos/shared_fromothers/polynomials_multiprecision/polynomials/include/polynomial/polynomial.hpp:1122:52: warning: unused typedef 'RTM' [-Wunused-local-typedef]
#             typedef number<mpfr_float_backend<M> > RTM;
#                                                    ^
# 14 warnings generated.

# %%
#generate code with the name, then manually modify GRF and parameters both in cpp and mathematica
#commenting out writing functions to avoid rewritting
obj=writescripts.PrepareFilesEqbindingmodels(varGRF="x",concvars=["x"],N=2,strategy="av")
obj.get_rhos_and_GRFs()

fname=os.path.join(folder,'N6univ.cpp')
funcname='N6univ'
#obj.write_pybind_interface(fname=fname, funcname=funcname)
#obj.write_checkfile_mathematica_singlevar(fname=fname.replace('.cpp','.wl'),min0=False, max1=False)
#obj.write_checksingleparset_mathematica_singlevar(fname=fname.replace('.cpp','.nb'),min0=False, max1=False)
# Out:
# ['K1', 'K2', 'w12']
# parlist is ['K1', 'K2', 'w12']
# GRF numerator:(1.0/2)*(rho2)+(1.0/2)*(rho3)+(2.0/2)*(rho4)
# GRF denominator:1*(rho1+rho2+rho3+rho4)
# 0
# 1

# %%
path_1,file=os.path.split(fname)
objectnamemac=os.path.join(path_1,file.replace('.cpp','')) 

compilestringmac="c++ -O2 -DNDEBUG -Wall -shared -std=c++11  -fPIC -undefined dynamic_lookup -I %s -lmpfr -lmpc -I %s  `python3 -m pybind11 --includes` %s -o %s`python3-config --extension-suffix`"%(path_to_polynomials,path_to_utilsGRF,fname,objectnamemac)

compilestring=compilestringmac
print(compilestring)

# !$compilestring
# Out:
# c++ -O2 -DNDEBUG -Wall -shared -std=c++11  -fPIC -undefined dynamic_lookup -I "/Users/rosamartinezcorral/Dropbox (HMS)/work2/shared_fromothers/polynomials_multiprecision/polynomials/include/polynomial/" -lmpfr -lmpc -I "/Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF"  `python3 -m pybind11 --includes` ../bin/N6univ.cpp -o ../bin/N6univ`python3-config --extension-suffix`
# In file included from ../bin/N6univ.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:667:17: warning: unused variable 'i2' [-Wunused-variable]
#     long double i2;
#                 ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:666:17: warning: unused variable 'i1' [-Wunused-variable]
#     long double i1;
#                 ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:512:11: warning: unused variable 'mincritpoint' [-Wunused-variable]
#         T mincritpoint;
#           ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/N6univ.cpp:63:90: note: in instantiation of member function 'GRFCalculations<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &N6univ_GRFCalculations<long double,mpc_50,polytype_50,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                          ^
# In file included from ../bin/N6univ.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:513:22: warning: unused variable 'thirdderx0' [-Wunused-variable]
#         T thirdderx, thirdderx0;
#                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:217:83: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type nnum, nden, degreenum, degreeden, degreesum, i, j;
#                                                                                   ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:403:5: note: in instantiation of function template specialization 'get_fraction_derivative_coeffs<long double>' requested here
#     get_fraction_derivative_coeffs<T>(num,den,derivativenum,derivativeden);
#     ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/N6univ.cpp:63:90: note: in instantiation of member function 'GRFCalculations<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &N6univ_GRFCalculations<long double,mpc_50,polytype_50,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                          ^
# In file included from ../bin/N6univ.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:665:38: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type i, j, nnum, nden;
#                                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:169:20: note: in instantiation of function template specialization 'compute_monotonic<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#             result=compute_monotonic<T,Tpolyc,polytype,thresholdtype>(num,den,thresholdimag); //return {-1} if derivative is 0, {-2} if no roots for the derivative of the GRF, -3 for each root out of the 10^-15,10^15 range, and the roots otherwise
#                    ^
# ../bin/N6univ.cpp:65:97: note: in instantiation of member function 'GRFCalculations<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfacemonotonic' requested here
#     .def("interfacemonotonic", &N6univ_GRFCalculations<long double,mpc_50,polytype_50,mpfr_15>::interfacemonotonic, py::arg("thresholdimag")=1e-15)
#                                                                                                 ^
# In file included from ../bin/N6univ.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:217:83: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type nnum, nden, degreenum, degreeden, degreesum, i, j;
#                                                                                   ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:403:5: note: in instantiation of function template specialization 'get_fraction_derivative_coeffs<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#     get_fraction_derivative_coeffs<T>(num,den,derivativenum,derivativeden);
#     ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/N6univ.cpp:74:86: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &N6univ_GRFCalculations<mpfr_50,mpc_50,polytype_50,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                      ^
# In file included from ../bin/N6univ.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:665:38: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type i, j, nnum, nden;
#                                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:169:20: note: in instantiation of function template specialization 'compute_monotonic<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#             result=compute_monotonic<T,Tpolyc,polytype,thresholdtype>(num,den,thresholdimag); //return {-1} if derivative is 0, {-2} if no roots for the derivative of the GRF, -3 for each root out of the 10^-15,10^15 range, and the roots otherwise
#                    ^
# ../bin/N6univ.cpp:76:93: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfacemonotonic' requested here
#     .def("interfacemonotonic", &N6univ_GRFCalculations<mpfr_50,mpc_50,polytype_50,mpfr_15>::interfacemonotonic, py::arg("thresholdimag")=1e-15)
#                                                                                             ^
# In file included from ../bin/N6univ.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:217:83: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type nnum, nden, degreenum, degreeden, degreesum, i, j;
#                                                                                   ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:403:5: note: in instantiation of function template specialization 'get_fraction_derivative_coeffs<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#     get_fraction_derivative_coeffs<T>(num,den,derivativenum,derivativeden);
#     ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/N6univ.cpp:85:89: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &N6univ_GRFCalculations<mpfr_100,mpc_100,polytype_100,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                         ^
# In file included from ../bin/N6univ.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:665:38: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type i, j, nnum, nden;
#                                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:169:20: note: in instantiation of function template specialization 'compute_monotonic<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#             result=compute_monotonic<T,Tpolyc,polytype,thresholdtype>(num,den,thresholdimag); //return {-1} if derivative is 0, {-2} if no roots for the derivative of the GRF, -3 for each root out of the 10^-15,10^15 range, and the roots otherwise
#                    ^
# ../bin/N6univ.cpp:87:96: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfacemonotonic' requested here
#     .def("interfacemonotonic", &N6univ_GRFCalculations<mpfr_100,mpc_100,polytype_100,mpfr_15>::interfacemonotonic, py::arg("thresholdimag")=1e-15)
#                                                                                                ^
# In file included from ../bin/N6univ.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:10:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared_fromothers/polynomials_multiprecision/polynomials/include/polynomial/polynomial.hpp:1122:52: warning: unused typedef 'RTM' [-Wunused-local-typedef]
#             typedef number<mpfr_float_backend<M> > RTM;
#                                                    ^
# 11 warnings generated.

# %% [markdown]
# # MWC model

# %%
#generate code with the name but as if it were av (simple code), then manually modify GRF and parameters both in cpp and mathematica
#commenting out writing functions to avoid rewritting
obj=writescripts.PrepareFilesEqbindingmodels(varGRF="x",concvars=["x"],N=2,strategy="av")
obj.get_rhos_and_GRFs()

fname=os.path.join(folder,'N4MWC.cpp')
funcname='N4MWC'
#obj.write_pybind_interface(fname=fname, funcname=funcname)
#obj.write_checkfile_mathematica_singlevar(fname=fname.replace('.cpp','.wl'),min0=True, max1=True)
#obj.write_checksingleparset_mathematica_singlevar(fname=fname.replace('.cpp','.nb'),min0=True, max1=True)
# Out:
# ['K1', 'K2', 'w12']
# parlist is ['K1', 'K2', 'w12']
# GRF numerator:(1.0/2)*(rho2)+(1.0/2)*(rho3)+(2.0/2)*(rho4)
# GRF denominator:1*(rho1+rho2+rho3+rho4)
# 0
# 1

# %%
path_1,file=os.path.split(fname)
objectnamemac=os.path.join(path_1,file.replace('.cpp','')) 

compilestringmac="c++ -O2 -DNDEBUG -Wall -shared -std=c++11  -fPIC -undefined dynamic_lookup -I %s -lmpfr -lmpc -I %s  `python3 -m pybind11 --includes` %s -o %s`python3-config --extension-suffix`"%(path_to_polynomials,path_to_utilsGRF,fname,objectnamemac)

compilestring=compilestringmac
print(compilestring)

# !$compilestring
# Out:
# c++ -O2 -DNDEBUG -Wall -shared -std=c++11  -fPIC -undefined dynamic_lookup -I "/Users/rosamartinezcorral/Dropbox (HMS)/work2/shared_fromothers/polynomials_multiprecision/polynomials/include/polynomial/" -lmpfr -lmpc -I "/Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF"  `python3 -m pybind11 --includes` ../bin/N4MWC.cpp -o ../bin/N4MWC`python3-config --extension-suffix`
# In file included from ../bin/N4MWC.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:667:17: warning: unused variable 'i2' [-Wunused-variable]
#     long double i2;
#                 ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:666:17: warning: unused variable 'i1' [-Wunused-variable]
#     long double i1;
#                 ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:512:11: warning: unused variable 'mincritpoint' [-Wunused-variable]
#         T mincritpoint;
#           ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/N4MWC.cpp:54:89: note: in instantiation of member function 'GRFCalculations<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &N4MWC_GRFCalculations<long double,mpc_50,polytype_50,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                         ^
# In file included from ../bin/N4MWC.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:513:22: warning: unused variable 'thirdderx0' [-Wunused-variable]
#         T thirdderx, thirdderx0;
#                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:217:83: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type nnum, nden, degreenum, degreeden, degreesum, i, j;
#                                                                                   ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:403:5: note: in instantiation of function template specialization 'get_fraction_derivative_coeffs<long double>' requested here
#     get_fraction_derivative_coeffs<T>(num,den,derivativenum,derivativeden);
#     ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/N4MWC.cpp:54:89: note: in instantiation of member function 'GRFCalculations<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &N4MWC_GRFCalculations<long double,mpc_50,polytype_50,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                         ^
# In file included from ../bin/N4MWC.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:665:38: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type i, j, nnum, nden;
#                                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:169:20: note: in instantiation of function template specialization 'compute_monotonic<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#             result=compute_monotonic<T,Tpolyc,polytype,thresholdtype>(num,den,thresholdimag); //return {-1} if derivative is 0, {-2} if no roots for the derivative of the GRF, -3 for each root out of the 10^-15,10^15 range, and the roots otherwise
#                    ^
# ../bin/N4MWC.cpp:56:96: note: in instantiation of member function 'GRFCalculations<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfacemonotonic' requested here
#     .def("interfacemonotonic", &N4MWC_GRFCalculations<long double,mpc_50,polytype_50,mpfr_15>::interfacemonotonic, py::arg("thresholdimag")=1e-15)
#                                                                                                ^
# In file included from ../bin/N4MWC.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:217:83: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type nnum, nden, degreenum, degreeden, degreesum, i, j;
#                                                                                   ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:403:5: note: in instantiation of function template specialization 'get_fraction_derivative_coeffs<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#     get_fraction_derivative_coeffs<T>(num,den,derivativenum,derivativeden);
#     ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/N4MWC.cpp:65:85: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &N4MWC_GRFCalculations<mpfr_50,mpc_50,polytype_50,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                     ^
# In file included from ../bin/N4MWC.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:665:38: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type i, j, nnum, nden;
#                                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:169:20: note: in instantiation of function template specialization 'compute_monotonic<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#             result=compute_monotonic<T,Tpolyc,polytype,thresholdtype>(num,den,thresholdimag); //return {-1} if derivative is 0, {-2} if no roots for the derivative of the GRF, -3 for each root out of the 10^-15,10^15 range, and the roots otherwise
#                    ^
# ../bin/N4MWC.cpp:67:92: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfacemonotonic' requested here
#     .def("interfacemonotonic", &N4MWC_GRFCalculations<mpfr_50,mpc_50,polytype_50,mpfr_15>::interfacemonotonic, py::arg("thresholdimag")=1e-15)
#                                                                                            ^
# In file included from ../bin/N4MWC.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:217:83: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type nnum, nden, degreenum, degreeden, degreesum, i, j;
#                                                                                   ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:403:5: note: in instantiation of function template specialization 'get_fraction_derivative_coeffs<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#     get_fraction_derivative_coeffs<T>(num,den,derivativenum,derivativeden);
#     ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/N4MWC.cpp:76:88: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &N4MWC_GRFCalculations<mpfr_100,mpc_100,polytype_100,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                        ^
# In file included from ../bin/N4MWC.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:665:38: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type i, j, nnum, nden;
#                                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:169:20: note: in instantiation of function template specialization 'compute_monotonic<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#             result=compute_monotonic<T,Tpolyc,polytype,thresholdtype>(num,den,thresholdimag); //return {-1} if derivative is 0, {-2} if no roots for the derivative of the GRF, -3 for each root out of the 10^-15,10^15 range, and the roots otherwise
#                    ^
# ../bin/N4MWC.cpp:78:95: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfacemonotonic' requested here
#     .def("interfacemonotonic", &N4MWC_GRFCalculations<mpfr_100,mpc_100,polytype_100,mpfr_15>::interfacemonotonic, py::arg("thresholdimag")=1e-15)
#                                                                                               ^
# In file included from ../bin/N4MWC.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:10:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared_fromothers/polynomials_multiprecision/polynomials/include/polynomial/polynomial.hpp:1122:52: warning: unused typedef 'RTM' [-Wunused-local-typedef]
#             typedef number<mpfr_float_backend<M> > RTM;
#                                                    ^
# 11 warnings generated.

# %%
#generate code with the name but as if it were av (simple code), then manually modify GRF and parameters both in cpp and mathematica
#commenting out writing functions to avoid rewritting
obj=writescripts.PrepareFilesEqbindingmodels(varGRF="x",concvars=["x"],N=2,strategy="av")
obj.get_rhos_and_GRFs()

fname=os.path.join(folder,'N6MWC.cpp')
funcname='N6MWC'
#obj.write_pybind_interface(fname=fname, funcname=funcname)
#obj.write_checkfile_mathematica_singlevar(fname=fname.replace('.cpp','.wl'),min0=True, max1=True)
#obj.write_checksingleparset_mathematica_singlevar(fname=fname.replace('.cpp','.nb'),min0=True, max1=True)
# Out:
# ['K1', 'K2', 'w12']
# parlist is ['K1', 'K2', 'w12']
# GRF numerator:(1.0/2)*(rho2)+(1.0/2)*(rho3)+(2.0/2)*(rho4)
# GRF denominator:1*(rho1+rho2+rho3+rho4)
# 0
# 1

# %%
path_1,file=os.path.split(fname)
objectnamemac=os.path.join(path_1,file.replace('.cpp','')) 

compilestringmac="c++ -O2 -DNDEBUG -Wall -shared -std=c++11  -fPIC -undefined dynamic_lookup -I %s -lmpfr -lmpc -I %s  `python3 -m pybind11 --includes` %s -o %s`python3-config --extension-suffix`"%(path_to_polynomials,path_to_utilsGRF,fname,objectnamemac)

compilestring=compilestringmac
print(compilestring)

# !$compilestring
# Out:
# c++ -O2 -DNDEBUG -Wall -shared -std=c++11  -fPIC -undefined dynamic_lookup -I "/Users/rosamartinezcorral/Dropbox (HMS)/work2/shared_fromothers/polynomials_multiprecision/polynomials/include/polynomial/" -lmpfr -lmpc -I "/Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF"  `python3 -m pybind11 --includes` ../bin/N6MWC.cpp -o ../bin/N6MWC`python3-config --extension-suffix`
# In file included from ../bin/N6MWC.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:667:17: warning: unused variable 'i2' [-Wunused-variable]
#     long double i2;
#                 ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:666:17: warning: unused variable 'i1' [-Wunused-variable]
#     long double i1;
#                 ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:512:11: warning: unused variable 'mincritpoint' [-Wunused-variable]
#         T mincritpoint;
#           ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/N6MWC.cpp:54:89: note: in instantiation of member function 'GRFCalculations<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &N6MWC_GRFCalculations<long double,mpc_50,polytype_50,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                         ^
# In file included from ../bin/N6MWC.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:513:22: warning: unused variable 'thirdderx0' [-Wunused-variable]
#         T thirdderx, thirdderx0;
#                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:217:83: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type nnum, nden, degreenum, degreeden, degreesum, i, j;
#                                                                                   ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:403:5: note: in instantiation of function template specialization 'get_fraction_derivative_coeffs<long double>' requested here
#     get_fraction_derivative_coeffs<T>(num,den,derivativenum,derivativeden);
#     ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/N6MWC.cpp:54:89: note: in instantiation of member function 'GRFCalculations<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &N6MWC_GRFCalculations<long double,mpc_50,polytype_50,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                         ^
# In file included from ../bin/N6MWC.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:665:38: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type i, j, nnum, nden;
#                                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:169:20: note: in instantiation of function template specialization 'compute_monotonic<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#             result=compute_monotonic<T,Tpolyc,polytype,thresholdtype>(num,den,thresholdimag); //return {-1} if derivative is 0, {-2} if no roots for the derivative of the GRF, -3 for each root out of the 10^-15,10^15 range, and the roots otherwise
#                    ^
# ../bin/N6MWC.cpp:56:96: note: in instantiation of member function 'GRFCalculations<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfacemonotonic' requested here
#     .def("interfacemonotonic", &N6MWC_GRFCalculations<long double,mpc_50,polytype_50,mpfr_15>::interfacemonotonic, py::arg("thresholdimag")=1e-15)
#                                                                                                ^
# In file included from ../bin/N6MWC.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:217:83: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type nnum, nden, degreenum, degreeden, degreesum, i, j;
#                                                                                   ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:403:5: note: in instantiation of function template specialization 'get_fraction_derivative_coeffs<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#     get_fraction_derivative_coeffs<T>(num,den,derivativenum,derivativeden);
#     ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/N6MWC.cpp:65:85: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &N6MWC_GRFCalculations<mpfr_50,mpc_50,polytype_50,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                     ^
# In file included from ../bin/N6MWC.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:665:38: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type i, j, nnum, nden;
#                                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:169:20: note: in instantiation of function template specialization 'compute_monotonic<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#             result=compute_monotonic<T,Tpolyc,polytype,thresholdtype>(num,den,thresholdimag); //return {-1} if derivative is 0, {-2} if no roots for the derivative of the GRF, -3 for each root out of the 10^-15,10^15 range, and the roots otherwise
#                    ^
# ../bin/N6MWC.cpp:67:92: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfacemonotonic' requested here
#     .def("interfacemonotonic", &N6MWC_GRFCalculations<mpfr_50,mpc_50,polytype_50,mpfr_15>::interfacemonotonic, py::arg("thresholdimag")=1e-15)
#                                                                                            ^
# In file included from ../bin/N6MWC.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:217:83: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type nnum, nden, degreenum, degreeden, degreesum, i, j;
#                                                                                   ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:403:5: note: in instantiation of function template specialization 'get_fraction_derivative_coeffs<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#     get_fraction_derivative_coeffs<T>(num,den,derivativenum,derivativeden);
#     ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/N6MWC.cpp:76:88: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &N6MWC_GRFCalculations<mpfr_100,mpc_100,polytype_100,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                        ^
# In file included from ../bin/N6MWC.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:665:38: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type i, j, nnum, nden;
#                                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:169:20: note: in instantiation of function template specialization 'compute_monotonic<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#             result=compute_monotonic<T,Tpolyc,polytype,thresholdtype>(num,den,thresholdimag); //return {-1} if derivative is 0, {-2} if no roots for the derivative of the GRF, -3 for each root out of the 10^-15,10^15 range, and the roots otherwise
#                    ^
# ../bin/N6MWC.cpp:78:95: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfacemonotonic' requested here
#     .def("interfacemonotonic", &N6MWC_GRFCalculations<mpfr_100,mpc_100,polytype_100,mpfr_15>::interfacemonotonic, py::arg("thresholdimag")=1e-15)
#                                                                                               ^
# In file included from ../bin/N6MWC.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:10:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared_fromothers/polynomials_multiprecision/polynomials/include/polynomial/polynomial.hpp:1122:52: warning: unused typedef 'RTM' [-Wunused-local-typedef]
#             typedef number<mpfr_float_backend<M> > RTM;
#                                                    ^
# 11 warnings generated.

# %% [markdown]
# # Pol model
#
# ## Expression =1 if at least one TF bound and pol bound (no basal expression)

# %%
#generate code that gives the GRF for the pol model with N=4 sites, with expression =1 from states with Pol and at least one TF site occupied.
obj=writescripts.PrepareFilesEqbindingmodels(varGRF="x",concvars=["x","P"],N=4,strategy="pol")
obj.get_rhos_and_GRFs()

fname=os.path.join(folder,'N4Pol.cpp')
funcname='N4Pol'
obj.write_pybind_interface(fname=fname, funcname=funcname)
obj.write_checkfile_mathematica_singlevar(fname=fname.replace('.cpp','.wl'),additionallinespars="P=1;\n",min0=True, max1=False)
obj.write_checksingleparset_mathematica_singlevar(fname=fname.replace('.cpp','.nb'),additionallinespars="P=1;\n",min0=True, max1=False)

path_1,file=os.path.split(fname)
objectnamemac=os.path.join(path_1,file.replace('.cpp','')) 

compilestringmac="c++ -O2 -DNDEBUG -Wall -shared -std=c++11  -fPIC -undefined dynamic_lookup -I %s -lmpfr -lmpc -I %s  `python3 -m pybind11 --includes` %s -o %s`python3-config --extension-suffix`"%(path_to_polynomials,path_to_utilsGRF,fname,objectnamemac)

compilestring=compilestringmac
print(compilestring)

# !$compilestring
# Out:
# ['K1', 'K2', 'K3', 'K4', 'w12', 'w13', 'w14', 'w23', 'w24', 'w34', 'w123', 'w124', 'w134', 'w234', 'w1234', 'wp1', 'wp2', 'wp3', 'wp4', 'wp12', 'wp13', 'wp14', 'wp23', 'wp24', 'wp34', 'wp123', 'wp124', 'wp134', 'wp234', 'wp1234']
# parlist is ['K1', 'K2', 'K3', 'K4', 'w12', 'w13', 'w14', 'w23', 'w24', 'w34', 'w123', 'w124', 'w134', 'w234', 'w1234', 'wp1', 'wp2', 'wp3', 'wp4', 'wp12', 'wp13', 'wp14', 'wp23', 'wp24', 'wp34', 'wp123', 'wp124', 'wp134', 'wp234', 'wp1234']
# GRF numerator:1*(rho10+rho13+rho15+rho16+rho19+rho21+rho22+rho24+rho25+rho26+rho28+rho29+rho30+rho31+rho32)
# GRF denominator:1*(rho1+rho2+rho3+rho4+rho5+rho6+rho7+rho8+rho9+rho10+rho11+rho12+rho13+rho14+rho15+rho16+rho17+rho18+rho19+rho20+rho21+rho22+rho23+rho24+rho25+rho26+rho27+rho28+rho29+rho30+rho31+rho32)
# 0
# 1
# writing mathematica file. max1 set to False
# K1_,K2_,K3_,K4_,w12_,w13_,w14_,w23_,w24_,w34_,w123_,w124_,w134_,w234_,w1234_,wp1_,wp2_,wp3_,wp4_,wp12_,wp13_,wp14_,wp23_,wp24_,wp34_,wp123_,wp124_,wp134_,wp234_,wp1234_,
# writing mathematica file. max1 set to False
# K1_,K2_,K3_,K4_,w12_,w13_,w14_,w23_,w24_,w34_,w123_,w124_,w134_,w234_,w1234_,wp1_,wp2_,wp3_,wp4_,wp12_,wp13_,wp14_,wp23_,wp24_,wp34_,wp123_,wp124_,wp134_,wp234_,wp1234_,
# c++ -O2 -DNDEBUG -Wall -shared -std=c++11  -fPIC -undefined dynamic_lookup -I "/Users/rosamartinezcorral/Dropbox (HMS)/work2/shared_fromothers/polynomials_multiprecision/polynomials/include/polynomial/" -lmpfr -lmpc -I "/Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF"  `python3 -m pybind11 --includes` ../bin/N4Pol.cpp -o ../bin/N4Pol`python3-config --extension-suffix`
# In file included from ../bin/N4Pol.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:667:17: warning: unused variable 'i2' [-Wunused-variable]
#     long double i2;
#                 ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:666:17: warning: unused variable 'i1' [-Wunused-variable]
#     long double i1;
#                 ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:512:11: warning: unused variable 'mincritpoint' [-Wunused-variable]
#         T mincritpoint;
#           ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/N4Pol.cpp:193:89: note: in instantiation of member function 'GRFCalculations<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &N4Pol_GRFCalculations<long double,mpc_50,polytype_50,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                         ^
# In file included from ../bin/N4Pol.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:513:22: warning: unused variable 'thirdderx0' [-Wunused-variable]
#         T thirdderx, thirdderx0;
#                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:217:83: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type nnum, nden, degreenum, degreeden, degreesum, i, j;
#                                                                                   ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:403:5: note: in instantiation of function template specialization 'get_fraction_derivative_coeffs<long double>' requested here
#     get_fraction_derivative_coeffs<T>(num,den,derivativenum,derivativeden);
#     ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/N4Pol.cpp:193:89: note: in instantiation of member function 'GRFCalculations<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &N4Pol_GRFCalculations<long double,mpc_50,polytype_50,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                         ^
# In file included from ../bin/N4Pol.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:665:38: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type i, j, nnum, nden;
#                                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:169:20: note: in instantiation of function template specialization 'compute_monotonic<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#             result=compute_monotonic<T,Tpolyc,polytype,thresholdtype>(num,den,thresholdimag); //return {-1} if derivative is 0, {-2} if no roots for the derivative of the GRF, -3 for each root out of the 10^-15,10^15 range, and the roots otherwise
#                    ^
# ../bin/N4Pol.cpp:195:96: note: in instantiation of member function 'GRFCalculations<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfacemonotonic' requested here
#     .def("interfacemonotonic", &N4Pol_GRFCalculations<long double,mpc_50,polytype_50,mpfr_15>::interfacemonotonic, py::arg("thresholdimag")=1e-15)
#                                                                                                ^
# In file included from ../bin/N4Pol.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:217:83: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type nnum, nden, degreenum, degreeden, degreesum, i, j;
#                                                                                   ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:403:5: note: in instantiation of function template specialization 'get_fraction_derivative_coeffs<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#     get_fraction_derivative_coeffs<T>(num,den,derivativenum,derivativeden);
#     ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/N4Pol.cpp:204:85: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &N4Pol_GRFCalculations<mpfr_50,mpc_50,polytype_50,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                     ^
# In file included from ../bin/N4Pol.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:665:38: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type i, j, nnum, nden;
#                                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:169:20: note: in instantiation of function template specialization 'compute_monotonic<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#             result=compute_monotonic<T,Tpolyc,polytype,thresholdtype>(num,den,thresholdimag); //return {-1} if derivative is 0, {-2} if no roots for the derivative of the GRF, -3 for each root out of the 10^-15,10^15 range, and the roots otherwise
#                    ^
# ../bin/N4Pol.cpp:206:92: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfacemonotonic' requested here
#     .def("interfacemonotonic", &N4Pol_GRFCalculations<mpfr_50,mpc_50,polytype_50,mpfr_15>::interfacemonotonic, py::arg("thresholdimag")=1e-15)
#                                                                                            ^
# In file included from ../bin/N4Pol.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:217:83: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type nnum, nden, degreenum, degreeden, degreesum, i, j;
#                                                                                   ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:403:5: note: in instantiation of function template specialization 'get_fraction_derivative_coeffs<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#     get_fraction_derivative_coeffs<T>(num,den,derivativenum,derivativeden);
#     ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/N4Pol.cpp:215:88: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &N4Pol_GRFCalculations<mpfr_100,mpc_100,polytype_100,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                        ^
# In file included from ../bin/N4Pol.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:665:38: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type i, j, nnum, nden;
#                                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:169:20: note: in instantiation of function template specialization 'compute_monotonic<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#             result=compute_monotonic<T,Tpolyc,polytype,thresholdtype>(num,den,thresholdimag); //return {-1} if derivative is 0, {-2} if no roots for the derivative of the GRF, -3 for each root out of the 10^-15,10^15 range, and the roots otherwise
#                    ^
# ../bin/N4Pol.cpp:217:95: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfacemonotonic' requested here
#     .def("interfacemonotonic", &N4Pol_GRFCalculations<mpfr_100,mpc_100,polytype_100,mpfr_15>::interfacemonotonic, py::arg("thresholdimag")=1e-15)
#                                                                                               ^
# In file included from ../bin/N4Pol.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:10:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared_fromothers/polynomials_multiprecision/polynomials/include/polynomial/polynomial.hpp:1122:52: warning: unused typedef 'RTM' [-Wunused-local-typedef]
#             typedef number<mpfr_float_backend<M> > RTM;
#                                                    ^
# 11 warnings generated.

# %%
obj=writescripts.PrepareFilesEqbindingmodels(varGRF="x",concvars=["x","P"],N=6,strategy="pol")
obj.get_rhos_and_GRFs()

fname=os.path.join(folder,'N6Pol.cpp')
funcname='N6Pol'
obj.write_pybind_interface(fname=fname, funcname=funcname)
obj.write_checkfile_mathematica_singlevar(fname=fname.replace('.cpp','.wl'),additionallinespars="P=1;\n",min0=True, max1=False)
obj.write_checksingleparset_mathematica_singlevar(fname=fname.replace('.cpp','.nb'),additionallinespars="P=1;\n",min0=True, max1=False)

path_1,file=os.path.split(fname)
objectnamemac=os.path.join(path_1,file.replace('.cpp','')) 

compilestringmac="c++ -O2 -DNDEBUG -Wall -shared -std=c++11  -fPIC -undefined dynamic_lookup -I %s -lmpfr -lmpc -I %s  `python3 -m pybind11 --includes` %s -o %s`python3-config --extension-suffix`"%(path_to_polynomials,path_to_utilsGRF,fname,objectnamemac)

compilestring=compilestringmac
print(compilestring)

# !$compilestring
# Out:
# ['K1', 'K2', 'K3', 'K4', 'K5', 'K6', 'w12', 'w13', 'w14', 'w15', 'w16', 'w23', 'w24', 'w25', 'w26', 'w34', 'w35', 'w36', 'w45', 'w46', 'w56', 'w123', 'w124', 'w125', 'w126', 'w134', 'w135', 'w136', 'w145', 'w146', 'w156', 'w234', 'w235', 'w236', 'w245', 'w246', 'w256', 'w345', 'w346', 'w356', 'w456', 'w1234', 'w1235', 'w1236', 'w1245', 'w1246', 'w1256', 'w1345', 'w1346', 'w1356', 'w1456', 'w2345', 'w2346', 'w2356', 'w2456', 'w3456', 'w12345', 'w12346', 'w12356', 'w12456', 'w13456', 'w23456', 'w123456', 'wp1', 'wp2', 'wp3', 'wp4', 'wp5', 'wp6', 'wp12', 'wp13', 'wp14', 'wp15', 'wp16', 'wp23', 'wp24', 'wp25', 'wp26', 'wp34', 'wp35', 'wp36', 'wp45', 'wp46', 'wp56', 'wp123', 'wp124', 'wp125', 'wp126', 'wp134', 'wp135', 'wp136', 'wp145', 'wp146', 'wp156', 'wp234', 'wp235', 'wp236', 'wp245', 'wp246', 'wp256', 'wp345', 'wp346', 'wp356', 'wp456', 'wp1234', 'wp1235', 'wp1236', 'wp1245', 'wp1246', 'wp1256', 'wp1345', 'wp1346', 'wp1356', 'wp1456', 'wp2345', 'wp2346', 'wp2356', 'wp2456', 'wp3456', 'wp12345', 'wp12346', 'wp12356', 'wp12456', 'wp13456', 'wp23456', 'wp123456']
# parlist is ['K1', 'K2', 'K3', 'K4', 'K5', 'K6', 'w12', 'w13', 'w14', 'w15', 'w16', 'w23', 'w24', 'w25', 'w26', 'w34', 'w35', 'w36', 'w45', 'w46', 'w56', 'w123', 'w124', 'w125', 'w126', 'w134', 'w135', 'w136', 'w145', 'w146', 'w156', 'w234', 'w235', 'w236', 'w245', 'w246', 'w256', 'w345', 'w346', 'w356', 'w456', 'w1234', 'w1235', 'w1236', 'w1245', 'w1246', 'w1256', 'w1345', 'w1346', 'w1356', 'w1456', 'w2345', 'w2346', 'w2356', 'w2456', 'w3456', 'w12345', 'w12346', 'w12356', 'w12456', 'w13456', 'w23456', 'w123456', 'wp1', 'wp2', 'wp3', 'wp4', 'wp5', 'wp6', 'wp12', 'wp13', 'wp14', 'wp15', 'wp16', 'wp23', 'wp24', 'wp25', 'wp26', 'wp34', 'wp35', 'wp36', 'wp45', 'wp46', 'wp56', 'wp123', 'wp124', 'wp125', 'wp126', 'wp134', 'wp135', 'wp136', 'wp145', 'wp146', 'wp156', 'wp234', 'wp235', 'wp236', 'wp245', 'wp246', 'wp256', 'wp345', 'wp346', 'wp356', 'wp456', 'wp1234', 'wp1235', 'wp1236', 'wp1245', 'wp1246', 'wp1256', 'wp1345', 'wp1346', 'wp1356', 'wp1456', 'wp2345', 'wp2346', 'wp2356', 'wp2456', 'wp3456', 'wp12345', 'wp12346', 'wp12356', 'wp12456', 'wp13456', 'wp23456', 'wp123456']
# GRF numerator:1*()
# GRF denominator:1*(...)
# 0
# 1
# writing mathematica file. max1 set to False
# K1_,K2_,K3_,K4_,K5_,K6_,w12_,w13_,w14_,w15_,w16_,w23_,w24_,w25_,w26_,w34_,w35_,w36_,w45_,w46_,w56_,w123_,w124_,w125_,w126_,w134_,w135_,w136_,w145_,w146_,w156_,w234_,w235_,w236_,w245_,w246_,w256_,w345_,w346_,w356_,w456_,w1234_,w1235_,w1236_,w1245_,w1246_,w1256_,w1345_,w1346_,w1356_,w1456_,w2345_,w2346_,w2356_,w2456_,w3456_,w12345_,w12346_,w12356_,w12456_,w13456_,w23456_,w123456_,wp1_,wp2_,wp3_,wp4_,wp5_,wp6_,wp12_,wp13_,wp14_,wp15_,wp16_,wp23_,wp24_,wp25_,wp26_,wp34_,wp35_,wp36_,wp45_,wp46_,wp56_,wp123_,wp124_,wp125_,wp126_,wp134_,wp135_,wp136_,wp145_,wp146_,wp156_,wp234_,wp235_,wp236_,wp245_,wp246_,wp256_,wp345_,wp346_,wp356_,wp456_,wp1234_,wp1235_,wp1236_,wp1245_,wp1246_,wp1256_,wp1345_,wp1346_,wp1356_,wp1456_,wp2345_,wp2346_,wp2356_,wp2456_,wp3456_,wp12345_,wp12346_,wp12356_,wp12456_,wp13456_,wp23456_,wp123456_,
# writing mathematica file. max1 set to False
# K1_,K2_,K3_,K4_,K5_,K6_,w12_,w13_,w14_,w15_,w16_,w23_,w24_,w25_,w26_,w34_,w35_,w36_,w45_,w46_,w56_,w123_,w124_,w125_,w126_,w134_,w135_,w136_,w145_,w146_,w156_,w234_,w235_,w236_,w245_,w246_,w256_,w345_,w346_,w356_,w456_,w1234_,w1235_,w1236_,w1245_,w1246_,w1256_,w1345_,w1346_,w1356_,w1456_,w2345_,w2346_,w2356_,w2456_,w3456_,w12345_,w12346_,w12356_,w12456_,w13456_,w23456_,w123456_,wp1_,wp2_,wp3_,wp4_,wp5_,wp6_,wp12_,wp13_,wp14_,wp15_,wp16_,wp23_,wp24_,wp25_,wp26_,wp34_,wp35_,wp36_,wp45_,wp46_,wp56_,wp123_,wp124_,wp125_,wp126_,wp134_,wp135_,wp136_,wp145_,wp146_,wp156_,wp234_,wp235_,wp236_,wp245_,wp246_,wp256_,wp345_,wp346_,wp356_,wp456_,wp1234_,wp1235_,wp1236_,wp1245_,wp1246_,wp1256_,wp1345_,wp1346_,wp1356_,wp1456_,wp2345_,wp2346_,wp2356_,wp2456_,wp3456_,wp12345_,wp12346_,wp12356_,wp12456_,wp13456_,wp23456_,wp123456_,
# c++ -O2 -DNDEBUG -Wall -shared -std=c++11  -fPIC -undefined dynamic_lookup -I "/Users/rosamartinezcorral/Dropbox (HMS)/work2/shared_fromothers/polynomials_multiprecision/polynomials/include/polynomial/" -lmpfr -lmpc -I "/Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF"  `python3 -m pybind11 --includes` ../bin/N6Pol.cpp -o ../bin/N6Pol`python3-config --extension-suffix`
# In file included from ../bin/N6Pol.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:667:17: warning: unused variable 'i2' [-Wunused-variable]
#     long double i2;
#                 ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:666:17: warning: unused variable 'i1' [-Wunused-variable]
#     long double i1;
#                 ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:512:11: warning: unused variable 'mincritpoint' [-Wunused-variable]
#         T mincritpoint;
#           ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/N6Pol.cpp:581:89: note: in instantiation of member function 'GRFCalculations<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &N6Pol_GRFCalculations<long double,mpc_50,polytype_50,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                         ^
# In file included from ../bin/N6Pol.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:513:22: warning: unused variable 'thirdderx0' [-Wunused-variable]
#         T thirdderx, thirdderx0;
#                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:217:83: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type nnum, nden, degreenum, degreeden, degreesum, i, j;
#                                                                                   ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:403:5: note: in instantiation of function template specialization 'get_fraction_derivative_coeffs<long double>' requested here
#     get_fraction_derivative_coeffs<T>(num,den,derivativenum,derivativeden);
#     ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/N6Pol.cpp:581:89: note: in instantiation of member function 'GRFCalculations<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &N6Pol_GRFCalculations<long double,mpc_50,polytype_50,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                         ^
# In file included from ../bin/N6Pol.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:665:38: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type i, j, nnum, nden;
#                                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:169:20: note: in instantiation of function template specialization 'compute_monotonic<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#             result=compute_monotonic<T,Tpolyc,polytype,thresholdtype>(num,den,thresholdimag); //return {-1} if derivative is 0, {-2} if no roots for the derivative of the GRF, -3 for each root out of the 10^-15,10^15 range, and the roots otherwise
#                    ^
# ../bin/N6Pol.cpp:583:96: note: in instantiation of member function 'GRFCalculations<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfacemonotonic' requested here
#     .def("interfacemonotonic", &N6Pol_GRFCalculations<long double,mpc_50,polytype_50,mpfr_15>::interfacemonotonic, py::arg("thresholdimag")=1e-15)
#                                                                                                ^
# In file included from ../bin/N6Pol.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:217:83: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type nnum, nden, degreenum, degreeden, degreesum, i, j;
#                                                                                   ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:403:5: note: in instantiation of function template specialization 'get_fraction_derivative_coeffs<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#     get_fraction_derivative_coeffs<T>(num,den,derivativenum,derivativeden);
#     ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/N6Pol.cpp:592:85: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &N6Pol_GRFCalculations<mpfr_50,mpc_50,polytype_50,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                     ^
# In file included from ../bin/N6Pol.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:665:38: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type i, j, nnum, nden;
#                                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:169:20: note: in instantiation of function template specialization 'compute_monotonic<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#             result=compute_monotonic<T,Tpolyc,polytype,thresholdtype>(num,den,thresholdimag); //return {-1} if derivative is 0, {-2} if no roots for the derivative of the GRF, -3 for each root out of the 10^-15,10^15 range, and the roots otherwise
#                    ^
# ../bin/N6Pol.cpp:594:92: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfacemonotonic' requested here
#     .def("interfacemonotonic", &N6Pol_GRFCalculations<mpfr_50,mpc_50,polytype_50,mpfr_15>::interfacemonotonic, py::arg("thresholdimag")=1e-15)
#                                                                                            ^
# In file included from ../bin/N6Pol.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:217:83: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type nnum, nden, degreenum, degreeden, degreesum, i, j;
#                                                                                   ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:403:5: note: in instantiation of function template specialization 'get_fraction_derivative_coeffs<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#     get_fraction_derivative_coeffs<T>(num,den,derivativenum,derivativeden);
#     ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/N6Pol.cpp:603:88: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &N6Pol_GRFCalculations<mpfr_100,mpc_100,polytype_100,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                        ^
# In file included from ../bin/N6Pol.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:665:38: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type i, j, nnum, nden;
#                                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:169:20: note: in instantiation of function template specialization 'compute_monotonic<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#             result=compute_monotonic<T,Tpolyc,polytype,thresholdtype>(num,den,thresholdimag); //return {-1} if derivative is 0, {-2} if no roots for the derivative of the GRF, -3 for each root out of the 10^-15,10^15 range, and the roots otherwise
#                    ^
# ../bin/N6Pol.cpp:605:95: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfacemonotonic' requested here
#     .def("interfacemonotonic", &N6Pol_GRFCalculations<mpfr_100,mpc_100,polytype_100,mpfr_15>::interfacemonotonic, py::arg("thresholdimag")=1e-15)
#                                                                                               ^
# In file included from ../bin/N6Pol.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:10:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared_fromothers/polynomials_multiprecision/polynomials/include/polynomial/polynomial.hpp:1122:52: warning: unused typedef 'RTM' [-Wunused-local-typedef]
#             typedef number<mpfr_float_backend<M> > RTM;
#                                                    ^
# 11 warnings generated.

# %% [markdown]
# ## Any cooperativity and basal expression
#
# Use writescripts.py to write the code.
#
#
# When executing the mathematica code to doublecheck: pass P as a command line:
# e.g.
# ```
# absder=True
# P=1000
# command="wolframscript -file ../../papers/universalb/bin/N6Pol_basal.wl '%s' '%s' '%s'"%(checkf, absder, P)
# ```

# %%
obj=writescripts.PrepareFilesEqbindingmodels(varGRF="x",concvars=["x","P"],N=4,strategy="pol_basal")
obj.get_rhos_and_GRFs()

fname=os.path.join(folder,'N4Pol_basal.cpp')
funcname='N4Pol_basal'
obj.write_pybind_interface(fname=fname, funcname=funcname)
obj.write_checkfile_mathematica_singlevar(fname=fname.replace('.cpp','.wl'),min0=False, max1=False)
obj.write_checksingleparset_mathematica_singlevar(fname=fname.replace('.cpp','.nb'),min0=False, max1=False)

path_1,file=os.path.split(fname)
objectnamemac=os.path.join(path_1,file.replace('.cpp','')) 

compilestringmac="c++ -O2 -DNDEBUG -Wall -shared -std=c++11  -fPIC -undefined dynamic_lookup -I %s -lmpfr -lmpc -I %s  `python3 -m pybind11 --includes` %s -o %s`python3-config --extension-suffix`"%(path_to_polynomials,path_to_utilsGRF,fname,objectnamemac)

compilestring=compilestringmac
print(compilestring)

# !$compilestring
# Out:
# ['K1', 'K2', 'K3', 'K4', 'w12', 'w13', 'w14', 'w23', 'w24', 'w34', 'w123', 'w124', 'w134', 'w234', 'w1234', 'wp1', 'wp2', 'wp3', 'wp4', 'wp12', 'wp13', 'wp14', 'wp23', 'wp24', 'wp34', 'wp123', 'wp124', 'wp134', 'wp234', 'wp1234']
# parlist is ['K1', 'K2', 'K3', 'K4', 'w12', 'w13', 'w14', 'w23', 'w24', 'w34', 'w123', 'w124', 'w134', 'w234', 'w1234', 'wp1', 'wp2', 'wp3', 'wp4', 'wp12', 'wp13', 'wp14', 'wp23', 'wp24', 'wp34', 'wp123', 'wp124', 'wp134', 'wp234', 'wp1234']
# GRF numerator:1*(rho6+rho10+rho13+rho15+rho16+rho19+rho21+rho22+rho24+rho25+rho26+rho28+rho29+rho30+rho31+rho32)
# GRF denominator:1*(rho1+rho2+rho3+rho4+rho5+rho6+rho7+rho8+rho9+rho10+rho11+rho12+rho13+rho14+rho15+rho16+rho17+rho18+rho19+rho20+rho21+rho22+rho23+rho24+rho25+rho26+rho27+rho28+rho29+rho30+rho31+rho32)
# 0
# 1
# writing mathematica file. max1 set to False
# There is more than 1 input variable. Pass a string to additionallinespars argument with the values corresponding to those
# K1_,K2_,K3_,K4_,w12_,w13_,w14_,w23_,w24_,w34_,w123_,w124_,w134_,w234_,w1234_,wp1_,wp2_,wp3_,wp4_,wp12_,wp13_,wp14_,wp23_,wp24_,wp34_,wp123_,wp124_,wp134_,wp234_,wp1234_,
# writing mathematica file. max1 set to False
# There is more than 1 input variable. Pass a string to additionallinespars argument with the values corresponding to those
# K1_,K2_,K3_,K4_,w12_,w13_,w14_,w23_,w24_,w34_,w123_,w124_,w134_,w234_,w1234_,wp1_,wp2_,wp3_,wp4_,wp12_,wp13_,wp14_,wp23_,wp24_,wp34_,wp123_,wp124_,wp134_,wp234_,wp1234_,
# c++ -O2 -DNDEBUG -Wall -shared -std=c++11  -fPIC -undefined dynamic_lookup -I "/Users/rosamartinezcorral/Dropbox (HMS)/work2/shared_fromothers/polynomials_multiprecision/polynomials/include/polynomial/" -lmpfr -lmpc -I "/Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF"  `python3 -m pybind11 --includes` ../bin/N4Pol_basal.cpp -o ../bin/N4Pol_basal`python3-config --extension-suffix`
# In file included from ../bin/N4Pol_basal.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:667:17: warning: unused variable 'i2' [-Wunused-variable]
#     long double i2;
#                 ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:666:17: warning: unused variable 'i1' [-Wunused-variable]
#     long double i1;
#                 ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:512:11: warning: unused variable 'mincritpoint' [-Wunused-variable]
#         T mincritpoint;
#           ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/N4Pol_basal.cpp:193:95: note: in instantiation of member function 'GRFCalculations<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &N4Pol_basal_GRFCalculations<long double,mpc_50,polytype_50,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                               ^
# In file included from ../bin/N4Pol_basal.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:513:22: warning: unused variable 'thirdderx0' [-Wunused-variable]
#         T thirdderx, thirdderx0;
#                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:217:83: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type nnum, nden, degreenum, degreeden, degreesum, i, j;
#                                                                                   ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:403:5: note: in instantiation of function template specialization 'get_fraction_derivative_coeffs<long double>' requested here
#     get_fraction_derivative_coeffs<T>(num,den,derivativenum,derivativeden);
#     ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/N4Pol_basal.cpp:193:95: note: in instantiation of member function 'GRFCalculations<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &N4Pol_basal_GRFCalculations<long double,mpc_50,polytype_50,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                               ^
# In file included from ../bin/N4Pol_basal.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:665:38: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type i, j, nnum, nden;
#                                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:169:20: note: in instantiation of function template specialization 'compute_monotonic<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#             result=compute_monotonic<T,Tpolyc,polytype,thresholdtype>(num,den,thresholdimag); //return {-1} if derivative is 0, {-2} if no roots for the derivative of the GRF, -3 for each root out of the 10^-15,10^15 range, and the roots otherwise
#                    ^
# ../bin/N4Pol_basal.cpp:195:102: note: in instantiation of member function 'GRFCalculations<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfacemonotonic' requested here
#     .def("interfacemonotonic", &N4Pol_basal_GRFCalculations<long double,mpc_50,polytype_50,mpfr_15>::interfacemonotonic, py::arg("thresholdimag")=1e-15)
#                                                                                                      ^
# In file included from ../bin/N4Pol_basal.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:217:83: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type nnum, nden, degreenum, degreeden, degreesum, i, j;
#                                                                                   ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:403:5: note: in instantiation of function template specialization 'get_fraction_derivative_coeffs<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#     get_fraction_derivative_coeffs<T>(num,den,derivativenum,derivativeden);
#     ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/N4Pol_basal.cpp:204:91: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &N4Pol_basal_GRFCalculations<mpfr_50,mpc_50,polytype_50,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                           ^
# In file included from ../bin/N4Pol_basal.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:665:38: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type i, j, nnum, nden;
#                                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:169:20: note: in instantiation of function template specialization 'compute_monotonic<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#             result=compute_monotonic<T,Tpolyc,polytype,thresholdtype>(num,den,thresholdimag); //return {-1} if derivative is 0, {-2} if no roots for the derivative of the GRF, -3 for each root out of the 10^-15,10^15 range, and the roots otherwise
#                    ^
# ../bin/N4Pol_basal.cpp:206:98: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfacemonotonic' requested here
#     .def("interfacemonotonic", &N4Pol_basal_GRFCalculations<mpfr_50,mpc_50,polytype_50,mpfr_15>::interfacemonotonic, py::arg("thresholdimag")=1e-15)
#                                                                                                  ^
# In file included from ../bin/N4Pol_basal.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:217:83: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type nnum, nden, degreenum, degreeden, degreesum, i, j;
#                                                                                   ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:403:5: note: in instantiation of function template specialization 'get_fraction_derivative_coeffs<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#     get_fraction_derivative_coeffs<T>(num,den,derivativenum,derivativeden);
#     ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/N4Pol_basal.cpp:215:94: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &N4Pol_basal_GRFCalculations<mpfr_100,mpc_100,polytype_100,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                              ^
# In file included from ../bin/N4Pol_basal.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:665:38: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type i, j, nnum, nden;
#                                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:169:20: note: in instantiation of function template specialization 'compute_monotonic<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#             result=compute_monotonic<T,Tpolyc,polytype,thresholdtype>(num,den,thresholdimag); //return {-1} if derivative is 0, {-2} if no roots for the derivative of the GRF, -3 for each root out of the 10^-15,10^15 range, and the roots otherwise
#                    ^
# ../bin/N4Pol_basal.cpp:217:101: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfacemonotonic' requested here
#     .def("interfacemonotonic", &N4Pol_basal_GRFCalculations<mpfr_100,mpc_100,polytype_100,mpfr_15>::interfacemonotonic, py::arg("thresholdimag")=1e-15)
#                                                                                                     ^
# In file included from ../bin/N4Pol_basal.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:10:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared_fromothers/polynomials_multiprecision/polynomials/include/polynomial/polynomial.hpp:1122:52: warning: unused typedef 'RTM' [-Wunused-local-typedef]
#             typedef number<mpfr_float_backend<M> > RTM;
#                                                    ^
# 11 warnings generated.

# %%
obj=writescripts.PrepareFilesEqbindingmodels(varGRF="x",concvars=["x","P"],N=6,strategy="pol_basal")
obj.get_rhos_and_GRFs()

fname=os.path.join(folder,'N6Pol_basal.cpp')
funcname='N6Pol_basal'
obj.write_pybind_interface(fname=fname, funcname=funcname)
obj.write_checkfile_mathematica_singlevar(fname=fname.replace('.cpp','.wl'),min0=False, max1=False)
obj.write_checksingleparset_mathematica_singlevar(fname=fname.replace('.cpp','.nb'),min0=False, max1=False)

path_1,file=os.path.split(fname)
objectnamemac=os.path.join(path_1,file.replace('.cpp','')) 

compilestringmac="c++ -O2 -DNDEBUG -Wall -shared -std=c++11  -fPIC -undefined dynamic_lookup -I %s -lmpfr -lmpc -I %s  `python3 -m pybind11 --includes` %s -o %s`python3-config --extension-suffix`"%(path_to_polynomials,path_to_utilsGRF,fname,objectnamemac)

compilestring=compilestringmac
print(compilestring)

# !$compilestring
# Out:
# ['K1', 'K2', 'K3', 'K4', 'K5', 'K6', 'w12', 'w13', 'w14', 'w15', 'w16', 'w23', 'w24', 'w25', 'w26', 'w34', 'w35', 'w36', 'w45', 'w46', 'w56', 'w123', 'w124', 'w125', 'w126', 'w134', 'w135', 'w136', 'w145', 'w146', 'w156', 'w234', 'w235', 'w236', 'w245', 'w246', 'w256', 'w345', 'w346', 'w356', 'w456', 'w1234', 'w1235', 'w1236', 'w1245', 'w1246', 'w1256', 'w1345', 'w1346', 'w1356', 'w1456', 'w2345', 'w2346', 'w2356', 'w2456', 'w3456', 'w12345', 'w12346', 'w12356', 'w12456', 'w13456', 'w23456', 'w123456', 'wp1', 'wp2', 'wp3', 'wp4', 'wp5', 'wp6', 'wp12', 'wp13', 'wp14', 'wp15', 'wp16', 'wp23', 'wp24', 'wp25', 'wp26', 'wp34', 'wp35', 'wp36', 'wp45', 'wp46', 'wp56', 'wp123', 'wp124', 'wp125', 'wp126', 'wp134', 'wp135', 'wp136', 'wp145', 'wp146', 'wp156', 'wp234', 'wp235', 'wp236', 'wp245', 'wp246', 'wp256', 'wp345', 'wp346', 'wp356', 'wp456', 'wp1234', 'wp1235', 'wp1236', 'wp1245', 'wp1246', 'wp1256', 'wp1345', 'wp1346', 'wp1356', 'wp1456', 'wp2345', 'wp2346', 'wp2356', 'wp2456', 'wp3456', 'wp12345', 'wp12346', 'wp12356', 'wp12456', 'wp13456', 'wp23456', 'wp123456']
# parlist is ['K1', 'K2', 'K3', 'K4', 'K5', 'K6', 'w12', 'w13', 'w14', 'w15', 'w16', 'w23', 'w24', 'w25', 'w26', 'w34', 'w35', 'w36', 'w45', 'w46', 'w56', 'w123', 'w124', 'w125', 'w126', 'w134', 'w135', 'w136', 'w145', 'w146', 'w156', 'w234', 'w235', 'w236', 'w245', 'w246', 'w256', 'w345', 'w346', 'w356', 'w456', 'w1234', 'w1235', 'w1236', 'w1245', 'w1246', 'w1256', 'w1345', 'w1346', 'w1356', 'w1456', 'w2345', 'w2346', 'w2356', 'w2456', 'w3456', 'w12345', 'w12346', 'w12356', 'w12456', 'w13456', 'w23456', 'w123456', 'wp1', 'wp2', 'wp3', 'wp4', 'wp5', 'wp6', 'wp12', 'wp13', 'wp14', 'wp15', 'wp16', 'wp23', 'wp24', 'wp25', 'wp26', 'wp34', 'wp35', 'wp36', 'wp45', 'wp46', 'wp56', 'wp123', 'wp124', 'wp125', 'wp126', 'wp134', 'wp135', 'wp136', 'wp145', 'wp146', 'wp156', 'wp234', 'wp235', 'wp236', 'wp245', 'wp246', 'wp256', 'wp345', 'wp346', 'wp356', 'wp456', 'wp1234', 'wp1235', 'wp1236', 'wp1245', 'wp1246', 'wp1256', 'wp1345', 'wp1346', 'wp1356', 'wp1456', 'wp2345', 'wp2346', 'wp2356', 'wp2456', 'wp3456', 'wp12345', 'wp12346', 'wp12356', 'wp12456', 'wp13456', 'wp23456', 'wp123456']
# GRF numerator:1*(...)
# GRF denominator:1*(...)
# 0
# 1
# writing mathematica file. max1 set to False
# There is more than 1 input variable. Pass a string to additionallinespars argument with the values corresponding to those
# K1_,K2_,K3_,K4_,K5_,K6_,w12_,w13_,w14_,w15_,w16_,w23_,w24_,w25_,w26_,w34_,w35_,w36_,w45_,w46_,w56_,w123_,w124_,w125_,w126_,w134_,w135_,w136_,w145_,w146_,w156_,w234_,w235_,w236_,w245_,w246_,w256_,w345_,w346_,w356_,w456_,w1234_,w1235_,w1236_,w1245_,w1246_,w1256_,w1345_,w1346_,w1356_,w1456_,w2345_,w2346_,w2356_,w2456_,w3456_,w12345_,w12346_,w12356_,w12456_,w13456_,w23456_,w123456_,wp1_,wp2_,wp3_,wp4_,wp5_,wp6_,wp12_,wp13_,wp14_,wp15_,wp16_,wp23_,wp24_,wp25_,wp26_,wp34_,wp35_,wp36_,wp45_,wp46_,wp56_,wp123_,wp124_,wp125_,wp126_,wp134_,wp135_,wp136_,wp145_,wp146_,wp156_,wp234_,wp235_,wp236_,wp245_,wp246_,wp256_,wp345_,wp346_,wp356_,wp456_,wp1234_,wp1235_,wp1236_,wp1245_,wp1246_,wp1256_,wp1345_,wp1346_,wp1356_,wp1456_,wp2345_,wp2346_,wp2356_,wp2456_,wp3456_,wp12345_,wp12346_,wp12356_,wp12456_,wp13456_,wp23456_,wp123456_,
# writing mathematica file. max1 set to False
# There is more than 1 input variable. Pass a string to additionallinespars argument with the values corresponding to those
# K1_,K2_,K3_,K4_,K5_,K6_,w12_,w13_,w14_,w15_,w16_,w23_,w24_,w25_,w26_,w34_,w35_,w36_,w45_,w46_,w56_,w123_,w124_,w125_,w126_,w134_,w135_,w136_,w145_,w146_,w156_,w234_,w235_,w236_,w245_,w246_,w256_,w345_,w346_,w356_,w456_,w1234_,w1235_,w1236_,w1245_,w1246_,w1256_,w1345_,w1346_,w1356_,w1456_,w2345_,w2346_,w2356_,w2456_,w3456_,w12345_,w12346_,w12356_,w12456_,w13456_,w23456_,w123456_,wp1_,wp2_,wp3_,wp4_,wp5_,wp6_,wp12_,wp13_,wp14_,wp15_,wp16_,wp23_,wp24_,wp25_,wp26_,wp34_,wp35_,wp36_,wp45_,wp46_,wp56_,wp123_,wp124_,wp125_,wp126_,wp134_,wp135_,wp136_,wp145_,wp146_,wp156_,wp234_,wp235_,wp236_,wp245_,wp246_,wp256_,wp345_,wp346_,wp356_,wp456_,wp1234_,wp1235_,wp1236_,wp1245_,wp1246_,wp1256_,wp1345_,wp1346_,wp1356_,wp1456_,wp2345_,wp2346_,wp2356_,wp2456_,wp3456_,wp12345_,wp12346_,wp12356_,wp12456_,wp13456_,wp23456_,wp123456_,
# c++ -O2 -DNDEBUG -Wall -shared -std=c++11  -fPIC -undefined dynamic_lookup -I "/Users/rosamartinezcorral/Dropbox (HMS)/work2/shared_fromothers/polynomials_multiprecision/polynomials/include/polynomial/" -lmpfr -lmpc -I "/Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF"  `python3 -m pybind11 --includes` ../bin/N6Pol_basal.cpp -o ../bin/N6Pol_basal`python3-config --extension-suffix`
# In file included from ../bin/N6Pol_basal.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:667:17: warning: unused variable 'i2' [-Wunused-variable]
#     long double i2;
#                 ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:666:17: warning: unused variable 'i1' [-Wunused-variable]
#     long double i1;
#                 ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:512:11: warning: unused variable 'mincritpoint' [-Wunused-variable]
#         T mincritpoint;
#           ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/N6Pol_basal.cpp:581:95: note: in instantiation of member function 'GRFCalculations<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &N6Pol_basal_GRFCalculations<long double,mpc_50,polytype_50,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                               ^
# In file included from ../bin/N6Pol_basal.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:513:22: warning: unused variable 'thirdderx0' [-Wunused-variable]
#         T thirdderx, thirdderx0;
#                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:217:83: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type nnum, nden, degreenum, degreeden, degreesum, i, j;
#                                                                                   ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:403:5: note: in instantiation of function template specialization 'get_fraction_derivative_coeffs<long double>' requested here
#     get_fraction_derivative_coeffs<T>(num,den,derivativenum,derivativeden);
#     ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/N6Pol_basal.cpp:581:95: note: in instantiation of member function 'GRFCalculations<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &N6Pol_basal_GRFCalculations<long double,mpc_50,polytype_50,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                               ^
# In file included from ../bin/N6Pol_basal.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:665:38: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type i, j, nnum, nden;
#                                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:169:20: note: in instantiation of function template specialization 'compute_monotonic<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#             result=compute_monotonic<T,Tpolyc,polytype,thresholdtype>(num,den,thresholdimag); //return {-1} if derivative is 0, {-2} if no roots for the derivative of the GRF, -3 for each root out of the 10^-15,10^15 range, and the roots otherwise
#                    ^
# ../bin/N6Pol_basal.cpp:583:102: note: in instantiation of member function 'GRFCalculations<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfacemonotonic' requested here
#     .def("interfacemonotonic", &N6Pol_basal_GRFCalculations<long double,mpc_50,polytype_50,mpfr_15>::interfacemonotonic, py::arg("thresholdimag")=1e-15)
#                                                                                                      ^
# In file included from ../bin/N6Pol_basal.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:217:83: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type nnum, nden, degreenum, degreeden, degreesum, i, j;
#                                                                                   ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:403:5: note: in instantiation of function template specialization 'get_fraction_derivative_coeffs<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#     get_fraction_derivative_coeffs<T>(num,den,derivativenum,derivativeden);
#     ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/N6Pol_basal.cpp:592:91: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &N6Pol_basal_GRFCalculations<mpfr_50,mpc_50,polytype_50,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                           ^
# In file included from ../bin/N6Pol_basal.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:665:38: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type i, j, nnum, nden;
#                                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:169:20: note: in instantiation of function template specialization 'compute_monotonic<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#             result=compute_monotonic<T,Tpolyc,polytype,thresholdtype>(num,den,thresholdimag); //return {-1} if derivative is 0, {-2} if no roots for the derivative of the GRF, -3 for each root out of the 10^-15,10^15 range, and the roots otherwise
#                    ^
# ../bin/N6Pol_basal.cpp:594:98: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfacemonotonic' requested here
#     .def("interfacemonotonic", &N6Pol_basal_GRFCalculations<mpfr_50,mpc_50,polytype_50,mpfr_15>::interfacemonotonic, py::arg("thresholdimag")=1e-15)
#                                                                                                  ^
# In file included from ../bin/N6Pol_basal.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:217:83: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type nnum, nden, degreenum, degreeden, degreesum, i, j;
#                                                                                   ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:403:5: note: in instantiation of function template specialization 'get_fraction_derivative_coeffs<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#     get_fraction_derivative_coeffs<T>(num,den,derivativenum,derivativeden);
#     ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/N6Pol_basal.cpp:603:94: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &N6Pol_basal_GRFCalculations<mpfr_100,mpc_100,polytype_100,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                              ^
# In file included from ../bin/N6Pol_basal.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:665:38: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type i, j, nnum, nden;
#                                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:169:20: note: in instantiation of function template specialization 'compute_monotonic<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#             result=compute_monotonic<T,Tpolyc,polytype,thresholdtype>(num,den,thresholdimag); //return {-1} if derivative is 0, {-2} if no roots for the derivative of the GRF, -3 for each root out of the 10^-15,10^15 range, and the roots otherwise
#                    ^
# ../bin/N6Pol_basal.cpp:605:101: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfacemonotonic' requested here
#     .def("interfacemonotonic", &N6Pol_basal_GRFCalculations<mpfr_100,mpc_100,polytype_100,mpfr_15>::interfacemonotonic, py::arg("thresholdimag")=1e-15)
#                                                                                                     ^
# In file included from ../bin/N6Pol_basal.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:10:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared_fromothers/polynomials_multiprecision/polynomials/include/polynomial/polynomial.hpp:1122:52: warning: unused typedef 'RTM' [-Wunused-local-typedef]
#             typedef number<mpfr_float_backend<M> > RTM;
#                                                    ^
# 11 warnings generated.

# %% [markdown]
# # Two TFs

# %%
sitedict={"1":"A","2":"A","3":"A","4":"A","5":"B","6":"B"}
obj=writescripts.PrepareFilesEqbindingmodels(varGRF="A",concvars=["A","B"],N=6,strategy="anyfi",sitedict=sitedict)
obj.get_rhos_and_GRFs()

fname=os.path.join(folder,'TFA4_TFB2.cpp')
funcname='TFA4_TFB2'
obj.write_pybind_interface(fname=fname, funcname=funcname)
obj.write_checkfile_mathematica_singlevar(fname=fname.replace('.cpp','.wl'),additionallinespars="B=1;\n",min0=False, max1=False)
obj.write_checksingleparset_mathematica_singlevar(fname=fname.replace('.cpp','.nb'),additionallinespars="B=1;\n",min0=False, max1=False)
# Out:
# ['K1', 'K2', 'K3', 'K4', 'K5', 'K6', 'w12', 'w13', 'w14', 'w15', 'w16', 'w23', 'w24', 'w25', 'w26', 'w34', 'w35', 'w36', 'w45', 'w46', 'w56', 'w123', 'w124', 'w125', 'w126', 'w134', 'w135', 'w136', 'w145', 'w146', 'w156', 'w234', 'w235', 'w236', 'w245', 'w246', 'w256', 'w345', 'w346', 'w356', 'w456', 'w1234', 'w1235', 'w1236', 'w1245', 'w1246', 'w1256', 'w1345', 'w1346', 'w1356', 'w1456', 'w2345', 'w2346', 'w2356', 'w2456', 'w3456', 'w12345', 'w12346', 'w12356', 'w12456', 'w13456', 'w23456', 'w123456']
# parlist is ['f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9', 'f10', 'f11', 'f12', 'f13', 'f14', 'f15', 'f16', 'f17', 'f18', 'f19', 'f20', 'f21', 'f22', 'f23', 'f24', 'f25', 'f26', 'f27', 'f28', 'f29', 'f30', 'f31', 'f32', 'f33', 'f34', 'f35', 'f36', 'f37', 'f38', 'f39', 'f40', 'f41', 'f42', 'f43', 'f44', 'f45', 'f46', 'f47', 'f48', 'f49', 'f50', 'f51', 'f52', 'f53', 'f54', 'f55', 'f56', 'f57', 'f58', 'f59', 'f60', 'f61', 'f62', 'f63', 'f64', 'K1', 'K2', 'K3', 'K4', 'K5', 'K6', 'w12', 'w13', 'w14', 'w15', 'w16', 'w23', 'w24', 'w25', 'w26', 'w34', 'w35', 'w36', 'w45', 'w46', 'w56', 'w123', 'w124', 'w125', 'w126', 'w134', 'w135', 'w136', 'w145', 'w146', 'w156', 'w234', 'w235', 'w236', 'w245', 'w246', 'w256', 'w345', 'w346', 'w356', 'w456', 'w1234', 'w1235', 'w1236', 'w1245', 'w1246', 'w1256', 'w1345', 'w1346', 'w1356', 'w1456', 'w2345', 'w2346', 'w2356', 'w2456', 'w3456', 'w12345', 'w12346', 'w12356', 'w12456', 'w13456', 'w23456', 'w123456']
# GRF numerator:(f1)*(rho1)+(f2)*(rho2)+(f3)*(rho3)+(f4)*(rho4)+(f5)*(rho5)+(f6)*(rho6)+(f7)*(rho7)+(f8)*(rho8)+(f9)*(rho9)+(f10)*(rho10)+(f11)*(rho11)+(f12)*(rho12)+(f13)*(rho13)+(f14)*(rho14)+(f15)*(rho15)+(f16)*(rho16)+(f17)*(rho17)+(f18)*(rho18)+(f19)*(rho19)+(f20)*(rho20)+(f21)*(rho21)+(f22)*(rho22)+(f23)*(rho23)+(f24)*(rho24)+(f25)*(rho25)+(f26)*(rho26)+(f27)*(rho27)+(f28)*(rho28)+(f29)*(rho29)+(f30)*(rho30)+(f31)*(rho31)+(f32)*(rho32)+(f33)*(rho33)+(f34)*(rho34)+(f35)*(rho35)+(f36)*(rho36)+(f37)*(rho37)+(f38)*(rho38)+(f39)*(rho39)+(f40)*(rho40)+(f41)*(rho41)+(f42)*(rho42)+(f43)*(rho43)+(f44)*(rho44)+(f45)*(rho45)+(f46)*(rho46)+(f47)*(rho47)+(f48)*(rho48)+(f49)*(rho49)+(f50)*(rho50)+(f51)*(rho51)+(f52)*(rho52)+(f53)*(rho53)+(f54)*(rho54)+(f55)*(rho55)+(f56)*(rho56)+(f57)*(rho57)+(f58)*(rho58)+(f59)*(rho59)+(f60)*(rho60)+(f61)*(rho61)+(f62)*(rho62)+(f63)*(rho63)+(f64)*(rho64)
# GRF denominator:1*()
# 0
# 1
# writing mathematica file. max1 set to False
# f1_,f2_,f3_,f4_,f5_,f6_,f7_,f8_,f9_,f10_,f11_,f12_,f13_,f14_,f15_,f16_,f17_,f18_,f19_,f20_,f21_,f22_,f23_,f24_,f25_,f26_,f27_,f28_,f29_,f30_,f31_,f32_,f33_,f34_,f35_,f36_,f37_,f38_,f39_,f40_,f41_,f42_,f43_,f44_,f45_,f46_,f47_,f48_,f49_,f50_,f51_,f52_,f53_,f54_,f55_,f56_,f57_,f58_,f59_,f60_,f61_,f62_,f63_,f64_,K1_,K2_,K3_,K4_,K5_,K6_,w12_,w13_,w14_,w15_,w16_,w23_,w24_,w25_,w26_,w34_,w35_,w36_,w45_,w46_,w56_,w123_,w124_,w125_,w126_,w134_,w135_,w136_,w145_,w146_,w156_,w234_,w235_,w236_,w245_,w246_,w256_,w345_,w346_,w356_,w456_,w1234_,w1235_,w1236_,w1245_,w1246_,w1256_,w1345_,w1346_,w1356_,w1456_,w2345_,w2346_,w2356_,w2456_,w3456_,w12345_,w12346_,w12356_,w12456_,w13456_,w23456_,w123456_,
# writing mathematica file. max1 set to False
# f1_,f2_,f3_,f4_,f5_,f6_,f7_,f8_,f9_,f10_,f11_,f12_,f13_,f14_,f15_,f16_,f17_,f18_,f19_,f20_,f21_,f22_,f23_,f24_,f25_,f26_,f27_,f28_,f29_,f30_,f31_,f32_,f33_,f34_,f35_,f36_,f37_,f38_,f39_,f40_,f41_,f42_,f43_,f44_,f45_,f46_,f47_,f48_,f49_,f50_,f51_,f52_,f53_,f54_,f55_,f56_,f57_,f58_,f59_,f60_,f61_,f62_,f63_,f64_,K1_,K2_,K3_,K4_,K5_,K6_,w12_,w13_,w14_,w15_,w16_,w23_,w24_,w25_,w26_,w34_,w35_,w36_,w45_,w46_,w56_,w123_,w124_,w125_,w126_,w134_,w135_,w136_,w145_,w146_,w156_,w234_,w235_,w236_,w245_,w246_,w256_,w345_,w346_,w356_,w456_,w1234_,w1235_,w1236_,w1245_,w1246_,w1256_,w1345_,w1346_,w1356_,w1456_,w2345_,w2346_,w2356_,w2456_,w3456_,w12345_,w12346_,w12356_,w12456_,w13456_,w23456_,w123456_,

# %% [markdown]
# Now manually replace std::pow for just pow.
#
# Replace ** for ^in the mathematica code.
#
# Also, for the case AminusBav, change the parameters so that the fiar is fixed.
#
# Using name TFA4_TFB2_AminusBav_manualfix for the mathematica files so they are not rewritten if the above code is executed again.

# %%
#Then compile
path_1,file=os.path.split(fname)
objectnamemac=os.path.join(path_1,file.replace('.cpp','')) 

compilestringmac="c++ -O2 -DNDEBUG -Wall -shared -std=c++11  -fPIC -undefined dynamic_lookup -I %s -lmpfr -lmpc -I %s  `python3 -m pybind11 --includes` %s -o %s`python3-config --extension-suffix`"%(path_to_polynomials,path_to_utilsGRF,fname,objectnamemac)

compilestring=compilestringmac
print(compilestring)

# !$compilestring
# Out:
# c++ -O2 -DNDEBUG -Wall -shared -std=c++11  -fPIC -undefined dynamic_lookup -I "/Users/rosamartinezcorral/Dropbox (HMS)/work2/shared_fromothers/polynomials_multiprecision/polynomials/include/polynomial/" -lmpfr -lmpc -I "/Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF"  `python3 -m pybind11 --includes` ../bin/TFA4_TFB2.cpp -o ../bin/TFA4_TFB2`python3-config --extension-suffix`
# In file included from ../bin/TFA4_TFB2.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:667:17: warning: unused variable 'i2' [-Wunused-variable]
#     long double i2;
#                 ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:666:17: warning: unused variable 'i1' [-Wunused-variable]
#     long double i1;
#                 ^
# ../bin/TFA4_TFB2.cpp:221:7: warning: unused variable 'f1' [-Wunused-variable]
#     T f1=pars[0];
#       ^
# ../bin/TFA4_TFB2.cpp:431:9: note: in instantiation of function template specialization 'rhos_TFA4_TFB2_A<long double>' requested here
#         rhos_TFA4_TFB2_A<T>(parsar, this->rhos,othervars, xval);
#         ^
# ../bin/TFA4_TFB2.cpp:448:91: note: in instantiation of member function 'TFA4_TFB2_GRFCalculations<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::fill_rhos' requested here
#     .def("fill_rhos", &TFA4_TFB2_GRFCalculations<long double,mpc_50,polytype_50,mpfr_15>::fill_rhos)
#                                                                                           ^
# ../bin/TFA4_TFB2.cpp:222:7: warning: unused variable 'f2' [-Wunused-variable]
#     T f2=pars[1];
#       ^
# ../bin/TFA4_TFB2.cpp:223:7: warning: unused variable 'f3' [-Wunused-variable]
#     T f3=pars[2];
#       ^
# ../bin/TFA4_TFB2.cpp:224:7: warning: unused variable 'f4' [-Wunused-variable]
#     T f4=pars[3];
#       ^
# ../bin/TFA4_TFB2.cpp:225:7: warning: unused variable 'f5' [-Wunused-variable]
#     T f5=pars[4];
#       ^
# ../bin/TFA4_TFB2.cpp:226:7: warning: unused variable 'f6' [-Wunused-variable]
#     T f6=pars[5];
#       ^
# ../bin/TFA4_TFB2.cpp:227:7: warning: unused variable 'f7' [-Wunused-variable]
#     T f7=pars[6];
#       ^
# ../bin/TFA4_TFB2.cpp:228:7: warning: unused variable 'f8' [-Wunused-variable]
#     T f8=pars[7];
#       ^
# ../bin/TFA4_TFB2.cpp:229:7: warning: unused variable 'f9' [-Wunused-variable]
#     T f9=pars[8];
#       ^
# ../bin/TFA4_TFB2.cpp:230:7: warning: unused variable 'f10' [-Wunused-variable]
#     T f10=pars[9];
#       ^
# ../bin/TFA4_TFB2.cpp:231:7: warning: unused variable 'f11' [-Wunused-variable]
#     T f11=pars[10];
#       ^
# ../bin/TFA4_TFB2.cpp:232:7: warning: unused variable 'f12' [-Wunused-variable]
#     T f12=pars[11];
#       ^
# ../bin/TFA4_TFB2.cpp:233:7: warning: unused variable 'f13' [-Wunused-variable]
#     T f13=pars[12];
#       ^
# ../bin/TFA4_TFB2.cpp:234:7: warning: unused variable 'f14' [-Wunused-variable]
#     T f14=pars[13];
#       ^
# ../bin/TFA4_TFB2.cpp:235:7: warning: unused variable 'f15' [-Wunused-variable]
#     T f15=pars[14];
#       ^
# ../bin/TFA4_TFB2.cpp:236:7: warning: unused variable 'f16' [-Wunused-variable]
#     T f16=pars[15];
#       ^
# ../bin/TFA4_TFB2.cpp:237:7: warning: unused variable 'f17' [-Wunused-variable]
#     T f17=pars[16];
#       ^
# ../bin/TFA4_TFB2.cpp:238:7: warning: unused variable 'f18' [-Wunused-variable]
#     T f18=pars[17];
#       ^
# ../bin/TFA4_TFB2.cpp:239:7: warning: unused variable 'f19' [-Wunused-variable]
#     T f19=pars[18];
#       ^
# ../bin/TFA4_TFB2.cpp:240:7: warning: unused variable 'f20' [-Wunused-variable]
#     T f20=pars[19];
#       ^
# ../bin/TFA4_TFB2.cpp:241:7: warning: unused variable 'f21' [-Wunused-variable]
#     T f21=pars[20];
#       ^
# ../bin/TFA4_TFB2.cpp:242:7: warning: unused variable 'f22' [-Wunused-variable]
#     T f22=pars[21];
#       ^
# ../bin/TFA4_TFB2.cpp:243:7: warning: unused variable 'f23' [-Wunused-variable]
#     T f23=pars[22];
#       ^
# ../bin/TFA4_TFB2.cpp:244:7: warning: unused variable 'f24' [-Wunused-variable]
#     T f24=pars[23];
#       ^
# ../bin/TFA4_TFB2.cpp:245:7: warning: unused variable 'f25' [-Wunused-variable]
#     T f25=pars[24];
#       ^
# ../bin/TFA4_TFB2.cpp:246:7: warning: unused variable 'f26' [-Wunused-variable]
#     T f26=pars[25];
#       ^
# ../bin/TFA4_TFB2.cpp:247:7: warning: unused variable 'f27' [-Wunused-variable]
#     T f27=pars[26];
#       ^
# ../bin/TFA4_TFB2.cpp:248:7: warning: unused variable 'f28' [-Wunused-variable]
#     T f28=pars[27];
#       ^
# ../bin/TFA4_TFB2.cpp:249:7: warning: unused variable 'f29' [-Wunused-variable]
#     T f29=pars[28];
#       ^
# ../bin/TFA4_TFB2.cpp:250:7: warning: unused variable 'f30' [-Wunused-variable]
#     T f30=pars[29];
#       ^
# ../bin/TFA4_TFB2.cpp:251:7: warning: unused variable 'f31' [-Wunused-variable]
#     T f31=pars[30];
#       ^
# ../bin/TFA4_TFB2.cpp:252:7: warning: unused variable 'f32' [-Wunused-variable]
#     T f32=pars[31];
#       ^
# ../bin/TFA4_TFB2.cpp:253:7: warning: unused variable 'f33' [-Wunused-variable]
#     T f33=pars[32];
#       ^
# ../bin/TFA4_TFB2.cpp:254:7: warning: unused variable 'f34' [-Wunused-variable]
#     T f34=pars[33];
#       ^
# ../bin/TFA4_TFB2.cpp:255:7: warning: unused variable 'f35' [-Wunused-variable]
#     T f35=pars[34];
#       ^
# ../bin/TFA4_TFB2.cpp:256:7: warning: unused variable 'f36' [-Wunused-variable]
#     T f36=pars[35];
#       ^
# ../bin/TFA4_TFB2.cpp:257:7: warning: unused variable 'f37' [-Wunused-variable]
#     T f37=pars[36];
#       ^
# ../bin/TFA4_TFB2.cpp:258:7: warning: unused variable 'f38' [-Wunused-variable]
#     T f38=pars[37];
#       ^
# ../bin/TFA4_TFB2.cpp:259:7: warning: unused variable 'f39' [-Wunused-variable]
#     T f39=pars[38];
#       ^
# ../bin/TFA4_TFB2.cpp:260:7: warning: unused variable 'f40' [-Wunused-variable]
#     T f40=pars[39];
#       ^
# ../bin/TFA4_TFB2.cpp:261:7: warning: unused variable 'f41' [-Wunused-variable]
#     T f41=pars[40];
#       ^
# ../bin/TFA4_TFB2.cpp:262:7: warning: unused variable 'f42' [-Wunused-variable]
#     T f42=pars[41];
#       ^
# ../bin/TFA4_TFB2.cpp:263:7: warning: unused variable 'f43' [-Wunused-variable]
#     T f43=pars[42];
#       ^
# ../bin/TFA4_TFB2.cpp:264:7: warning: unused variable 'f44' [-Wunused-variable]
#     T f44=pars[43];
#       ^
# ../bin/TFA4_TFB2.cpp:265:7: warning: unused variable 'f45' [-Wunused-variable]
#     T f45=pars[44];
#       ^
# ../bin/TFA4_TFB2.cpp:266:7: warning: unused variable 'f46' [-Wunused-variable]
#     T f46=pars[45];
#       ^
# ../bin/TFA4_TFB2.cpp:267:7: warning: unused variable 'f47' [-Wunused-variable]
#     T f47=pars[46];
#       ^
# ../bin/TFA4_TFB2.cpp:268:7: warning: unused variable 'f48' [-Wunused-variable]
#     T f48=pars[47];
#       ^
# ../bin/TFA4_TFB2.cpp:269:7: warning: unused variable 'f49' [-Wunused-variable]
#     T f49=pars[48];
#       ^
# ../bin/TFA4_TFB2.cpp:270:7: warning: unused variable 'f50' [-Wunused-variable]
#     T f50=pars[49];
#       ^
# ../bin/TFA4_TFB2.cpp:271:7: warning: unused variable 'f51' [-Wunused-variable]
#     T f51=pars[50];
#       ^
# ../bin/TFA4_TFB2.cpp:272:7: warning: unused variable 'f52' [-Wunused-variable]
#     T f52=pars[51];
#       ^
# ../bin/TFA4_TFB2.cpp:273:7: warning: unused variable 'f53' [-Wunused-variable]
#     T f53=pars[52];
#       ^
# ../bin/TFA4_TFB2.cpp:274:7: warning: unused variable 'f54' [-Wunused-variable]
#     T f54=pars[53];
#       ^
# ../bin/TFA4_TFB2.cpp:275:7: warning: unused variable 'f55' [-Wunused-variable]
#     T f55=pars[54];
#       ^
# ../bin/TFA4_TFB2.cpp:276:7: warning: unused variable 'f56' [-Wunused-variable]
#     T f56=pars[55];
#       ^
# ../bin/TFA4_TFB2.cpp:277:7: warning: unused variable 'f57' [-Wunused-variable]
#     T f57=pars[56];
#       ^
# ../bin/TFA4_TFB2.cpp:278:7: warning: unused variable 'f58' [-Wunused-variable]
#     T f58=pars[57];
#       ^
# ../bin/TFA4_TFB2.cpp:279:7: warning: unused variable 'f59' [-Wunused-variable]
#     T f59=pars[58];
#       ^
# ../bin/TFA4_TFB2.cpp:280:7: warning: unused variable 'f60' [-Wunused-variable]
#     T f60=pars[59];
#       ^
# ../bin/TFA4_TFB2.cpp:281:7: warning: unused variable 'f61' [-Wunused-variable]
#     T f61=pars[60];
#       ^
# ../bin/TFA4_TFB2.cpp:282:7: warning: unused variable 'f62' [-Wunused-variable]
#     T f62=pars[61];
#       ^
# ../bin/TFA4_TFB2.cpp:283:7: warning: unused variable 'f63' [-Wunused-variable]
#     T f63=pars[62];
#       ^
# ../bin/TFA4_TFB2.cpp:284:7: warning: unused variable 'f64' [-Wunused-variable]
#     T f64=pars[63];
#       ^
# In file included from ../bin/TFA4_TFB2.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:512:11: warning: unused variable 'mincritpoint' [-Wunused-variable]
#         T mincritpoint;
#           ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/TFA4_TFB2.cpp:451:93: note: in instantiation of member function 'GRFCalculations<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &TFA4_TFB2_GRFCalculations<long double,mpc_50,polytype_50,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                             ^
# In file included from ../bin/TFA4_TFB2.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:513:22: warning: unused variable 'thirdderx0' [-Wunused-variable]
#         T thirdderx, thirdderx0;
#                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:217:83: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type nnum, nden, degreenum, degreeden, degreesum, i, j;
#                                                                                   ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:403:5: note: in instantiation of function template specialization 'get_fraction_derivative_coeffs<long double>' requested here
#     get_fraction_derivative_coeffs<T>(num,den,derivativenum,derivativeden);
#     ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/TFA4_TFB2.cpp:451:93: note: in instantiation of member function 'GRFCalculations<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &TFA4_TFB2_GRFCalculations<long double,mpc_50,polytype_50,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                             ^
# In file included from ../bin/TFA4_TFB2.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:665:38: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type i, j, nnum, nden;
#                                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:169:20: note: in instantiation of function template specialization 'compute_monotonic<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#             result=compute_monotonic<T,Tpolyc,polytype,thresholdtype>(num,den,thresholdimag); //return {-1} if derivative is 0, {-2} if no roots for the derivative of the GRF, -3 for each root out of the 10^-15,10^15 range, and the roots otherwise
#                    ^
# ../bin/TFA4_TFB2.cpp:453:100: note: in instantiation of member function 'GRFCalculations<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfacemonotonic' requested here
#     .def("interfacemonotonic", &TFA4_TFB2_GRFCalculations<long double,mpc_50,polytype_50,mpfr_15>::interfacemonotonic, py::arg("thresholdimag")=1e-15)
#                                                                                                    ^
# In file included from ../bin/TFA4_TFB2.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:217:83: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type nnum, nden, degreenum, degreeden, degreesum, i, j;
#                                                                                   ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:403:5: note: in instantiation of function template specialization 'get_fraction_derivative_coeffs<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#     get_fraction_derivative_coeffs<T>(num,den,derivativenum,derivativeden);
#     ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/TFA4_TFB2.cpp:462:89: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &TFA4_TFB2_GRFCalculations<mpfr_50,mpc_50,polytype_50,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                         ^
# In file included from ../bin/TFA4_TFB2.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:665:38: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type i, j, nnum, nden;
#                                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:169:20: note: in instantiation of function template specialization 'compute_monotonic<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#             result=compute_monotonic<T,Tpolyc,polytype,thresholdtype>(num,den,thresholdimag); //return {-1} if derivative is 0, {-2} if no roots for the derivative of the GRF, -3 for each root out of the 10^-15,10^15 range, and the roots otherwise
#                    ^
# ../bin/TFA4_TFB2.cpp:464:96: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfacemonotonic' requested here
#     .def("interfacemonotonic", &TFA4_TFB2_GRFCalculations<mpfr_50,mpc_50,polytype_50,mpfr_15>::interfacemonotonic, py::arg("thresholdimag")=1e-15)
#                                                                                                ^
# In file included from ../bin/TFA4_TFB2.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:217:83: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type nnum, nden, degreenum, degreeden, degreesum, i, j;
#                                                                                   ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:403:5: note: in instantiation of function template specialization 'get_fraction_derivative_coeffs<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#     get_fraction_derivative_coeffs<T>(num,den,derivativenum,derivativeden);
#     ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/TFA4_TFB2.cpp:473:92: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &TFA4_TFB2_GRFCalculations<mpfr_100,mpc_100,polytype_100,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                            ^
# In file included from ../bin/TFA4_TFB2.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:665:38: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type i, j, nnum, nden;
#                                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:169:20: note: in instantiation of function template specialization 'compute_monotonic<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#             result=compute_monotonic<T,Tpolyc,polytype,thresholdtype>(num,den,thresholdimag); //return {-1} if derivative is 0, {-2} if no roots for the derivative of the GRF, -3 for each root out of the 10^-15,10^15 range, and the roots otherwise
#                    ^
# ../bin/TFA4_TFB2.cpp:475:99: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfacemonotonic' requested here
#     .def("interfacemonotonic", &TFA4_TFB2_GRFCalculations<mpfr_100,mpc_100,polytype_100,mpfr_15>::interfacemonotonic, py::arg("thresholdimag")=1e-15)
#                                                                                                   ^
# In file included from ../bin/TFA4_TFB2.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:10:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared_fromothers/polynomials_multiprecision/polynomials/include/polynomial/polynomial.hpp:1122:52: warning: unused typedef 'RTM' [-Wunused-local-typedef]
#             typedef number<mpfr_float_backend<M> > RTM;
#                                                    ^
# 75 warnings generated.

# %% [markdown]
# For the code TFA4_TFB2_allornone, copy-paste the previous .cpp file and manually modify so that the numerator of the GRF corresponds to that regulatory strategy.
#
# numerator of degree 0, 1, 2, 3 to 0. numdeg4=coeffs_43[4];

# %%
fname=os.path.join(folder,'TFA4_TFB2_allornone.cpp')
funcname='TFA4_TFB2_allornone'

# %%
path_1,file=os.path.split(fname)
objectnamemac=os.path.join(path_1,file.replace('.cpp','')) 

compilestringmac="c++ -O2 -DNDEBUG -Wall -shared -std=c++11  -fPIC -undefined dynamic_lookup -I %s -lmpfr -lmpc -I %s  `python3 -m pybind11 --includes` %s -o %s`python3-config --extension-suffix`"%(path_to_polynomials,path_to_utilsGRF,fname,objectnamemac)

compilestring=compilestringmac
print(compilestring)

# !$compilestring
# Out:
# c++ -O2 -DNDEBUG -Wall -shared -std=c++11  -fPIC -undefined dynamic_lookup -I "/Users/rosamartinezcorral/Dropbox (HMS)/work2/shared_fromothers/polynomials_multiprecision/polynomials/include/polynomial/" -lmpfr -lmpc -I "/Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF"  `python3 -m pybind11 --includes` ../bin/TFA4_TFB2_allornone.cpp -o ../bin/TFA4_TFB2_allornone`python3-config --extension-suffix`
# In file included from ../bin/TFA4_TFB2_allornone.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:667:17: warning: unused variable 'i2' [-Wunused-variable]
#     long double i2;
#                 ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:666:17: warning: unused variable 'i1' [-Wunused-variable]
#     long double i1;
#                 ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:512:11: warning: unused variable 'mincritpoint' [-Wunused-variable]
#         T mincritpoint;
#           ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/TFA4_TFB2_allornone.cpp:325:103: note: in instantiation of member function 'GRFCalculations<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &TFA4_TFB2_allornone_GRFCalculations<long double,mpc_50,polytype_50,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                                       ^
# In file included from ../bin/TFA4_TFB2_allornone.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:513:22: warning: unused variable 'thirdderx0' [-Wunused-variable]
#         T thirdderx, thirdderx0;
#                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:217:83: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type nnum, nden, degreenum, degreeden, degreesum, i, j;
#                                                                                   ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:403:5: note: in instantiation of function template specialization 'get_fraction_derivative_coeffs<long double>' requested here
#     get_fraction_derivative_coeffs<T>(num,den,derivativenum,derivativeden);
#     ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/TFA4_TFB2_allornone.cpp:325:103: note: in instantiation of member function 'GRFCalculations<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &TFA4_TFB2_allornone_GRFCalculations<long double,mpc_50,polytype_50,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                                       ^
# In file included from ../bin/TFA4_TFB2_allornone.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:665:38: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type i, j, nnum, nden;
#                                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:169:20: note: in instantiation of function template specialization 'compute_monotonic<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#             result=compute_monotonic<T,Tpolyc,polytype,thresholdtype>(num,den,thresholdimag); //return {-1} if derivative is 0, {-2} if no roots for the derivative of the GRF, -3 for each root out of the 10^-15,10^15 range, and the roots otherwise
#                    ^
# ../bin/TFA4_TFB2_allornone.cpp:327:110: note: in instantiation of member function 'GRFCalculations<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfacemonotonic' requested here
#     .def("interfacemonotonic", &TFA4_TFB2_allornone_GRFCalculations<long double,mpc_50,polytype_50,mpfr_15>::interfacemonotonic, py::arg("thresholdimag")=1e-15)
#                                                                                                              ^
# In file included from ../bin/TFA4_TFB2_allornone.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:217:83: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type nnum, nden, degreenum, degreeden, degreesum, i, j;
#                                                                                   ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:403:5: note: in instantiation of function template specialization 'get_fraction_derivative_coeffs<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#     get_fraction_derivative_coeffs<T>(num,den,derivativenum,derivativeden);
#     ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/TFA4_TFB2_allornone.cpp:336:99: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &TFA4_TFB2_allornone_GRFCalculations<mpfr_50,mpc_50,polytype_50,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                                   ^
# In file included from ../bin/TFA4_TFB2_allornone.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:665:38: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type i, j, nnum, nden;
#                                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:169:20: note: in instantiation of function template specialization 'compute_monotonic<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#             result=compute_monotonic<T,Tpolyc,polytype,thresholdtype>(num,den,thresholdimag); //return {-1} if derivative is 0, {-2} if no roots for the derivative of the GRF, -3 for each root out of the 10^-15,10^15 range, and the roots otherwise
#                    ^
# ../bin/TFA4_TFB2_allornone.cpp:338:106: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfacemonotonic' requested here
#     .def("interfacemonotonic", &TFA4_TFB2_allornone_GRFCalculations<mpfr_50,mpc_50,polytype_50,mpfr_15>::interfacemonotonic, py::arg("thresholdimag")=1e-15)
#                                                                                                          ^
# In file included from ../bin/TFA4_TFB2_allornone.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:217:83: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type nnum, nden, degreenum, degreeden, degreesum, i, j;
#                                                                                   ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:403:5: note: in instantiation of function template specialization 'get_fraction_derivative_coeffs<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#     get_fraction_derivative_coeffs<T>(num,den,derivativenum,derivativeden);
#     ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/TFA4_TFB2_allornone.cpp:347:102: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &TFA4_TFB2_allornone_GRFCalculations<mpfr_100,mpc_100,polytype_100,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                                      ^
# In file included from ../bin/TFA4_TFB2_allornone.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:665:38: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type i, j, nnum, nden;
#                                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:169:20: note: in instantiation of function template specialization 'compute_monotonic<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#             result=compute_monotonic<T,Tpolyc,polytype,thresholdtype>(num,den,thresholdimag); //return {-1} if derivative is 0, {-2} if no roots for the derivative of the GRF, -3 for each root out of the 10^-15,10^15 range, and the roots otherwise
#                    ^
# ../bin/TFA4_TFB2_allornone.cpp:349:109: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfacemonotonic' requested here
#     .def("interfacemonotonic", &TFA4_TFB2_allornone_GRFCalculations<mpfr_100,mpc_100,polytype_100,mpfr_15>::interfacemonotonic, py::arg("thresholdimag")=1e-15)
#                                                                                                             ^
# In file included from ../bin/TFA4_TFB2_allornone.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:10:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared_fromothers/polynomials_multiprecision/polynomials/include/polynomial/polynomial.hpp:1122:52: warning: unused typedef 'RTM' [-Wunused-local-typedef]
#             typedef number<mpfr_float_backend<M> > RTM;
#                                                    ^
# 11 warnings generated.

# %% [markdown]
# # Noneq av model

# %% [markdown]
# See notebook codehypercubeN4noneq...

# %% [markdown]
# # hypercube with arbitrary rates

# %% [markdown]
# Here I'm reusing the N4av and previous code I had built:

# %% [markdown]
# 1. Copy-paste N4av.cpp into N4arbfi.cpp.
# 2. Change name from N4av_x into N4arbfi_x, and change the parameters and GRF coefficients by what is below. (old code done previously). Change also the name of the rhos function and the parameter list.
# 3. Change class name into N4arbfi_GRFcalculations, and name of functions inside.
# 4. Change module name and class name in module definition part.

# %%
long double f1=pars[0];
long double f2=pars[1];
long double f3=pars[2];
long double f4=pars[3];
long double f5=pars[4];
long double f6=pars[5];
long double f7=pars[6];
long double f8=pars[7];
long double f9=pars[8];
long double f10=pars[9];
long double f11=pars[10];
long double f12=pars[11];
long double f13=pars[12];
long double f14=pars[13];
long double f15=pars[14];
long double f16=pars[15];
long double K1=pars[16];
long double K2=pars[17];
long double K3=pars[18];
long double K4=pars[19];
long double w12=pars[20];
long double w13=pars[21];
long double w14=pars[22];
long double w23=pars[23];
long double w24=pars[24];
long double w34=pars[25];
long double w123=pars[26];
long double w124=pars[27];
long double w134=pars[28];
long double w234=pars[29];
long double w1234=pars[30];

T numdeg0=(f1)*coeffs_1[0];
T numdeg1=(f2)*coeffs_2[1]+(f3)*coeffs_3[1]+(f4)*coeffs_4[1]+(f5)*coeffs_5[1];
T numdeg2=(f6)*coeffs_6[2]+(f7)*coeffs_7[2]+(f8)*coeffs_8[2]+(f9)*coeffs_9[2]+(f10)*coeffs_10[2]+(f11)*coeffs_11[2];
T numdeg3=(f12)*coeffs_12[3]+(f13)*coeffs_13[3]+(f14)*coeffs_14[3]+(f15)*coeffs_15[3];
T numdeg4=(f16)*coeffs_16[4];
T dendeg0=coeffs_1[0];
T dendeg1=coeffs_2[1]+coeffs_3[1]+coeffs_4[1]+coeffs_5[1];
T dendeg2=coeffs_6[2]+coeffs_7[2]+coeffs_8[2]+coeffs_9[2]+coeffs_10[2]+coeffs_11[2];
T dendeg3=coeffs_12[3]+coeffs_13[3]+coeffs_14[3]+coeffs_15[3];
T dendeg4=coeffs_16[4];

# %%
fname='../bin/N4arbfi.cpp'
path_1,file=os.path.split(fname)
objectnamemac=os.path.join(path_1,file.replace('.cpp','')) 

compilestringmac="c++ -O2 -DNDEBUG -Wall -shared -std=c++11  -fPIC -undefined dynamic_lookup -I %s -lmpfr -lmpc -I %s  `python3 -m pybind11 --includes` %s -o %s`python3-config --extension-suffix`"%(path_to_polynomials,path_to_utilsGRF,fname,objectnamemac)
compilestring=compilestringmac
print(compilestring)

! $compilestring
# Out:
# c++ -O2 -DNDEBUG -Wall -shared -std=c++11  -fPIC -undefined dynamic_lookup -I "/Users/rosamartinezcorral/Dropbox (HMS)/work2/shared_fromothers/polynomials_multiprecision/polynomials/include/polynomial/" -lmpfr -lmpc -I "/Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF"  `python3 -m pybind11 --includes` ../bin/N4arbfi.cpp -o ../bin/N4arbfi`python3-config --extension-suffix`
# In file included from ../bin/N4arbfi.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:667:17: warning: unused variable 'i2' [-Wunused-variable]
#     long double i2;
#                 ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:666:17: warning: unused variable 'i1' [-Wunused-variable]
#     long double i1;
#                 ^
# ../bin/N4arbfi.cpp:40:13: warning: unused variable 'varsar' [-Wunused-variable]
#     double *varsar=(double *) varsarbuf.ptr;
#             ^
# ../bin/N4arbfi.cpp:79:17: warning: unused variable 'f4' [-Wunused-variable]
#     long double f4=pars[3];
#                 ^
# ../bin/N4arbfi.cpp:85:17: warning: unused variable 'f10' [-Wunused-variable]
#     long double f10=pars[9];
#                 ^
# ../bin/N4arbfi.cpp:78:17: warning: unused variable 'f3' [-Wunused-variable]
#     long double f3=pars[2];
#                 ^
# ../bin/N4arbfi.cpp:84:17: warning: unused variable 'f9' [-Wunused-variable]
#     long double f9=pars[8];
#                 ^
# ../bin/N4arbfi.cpp:77:17: warning: unused variable 'f2' [-Wunused-variable]
#     long double f2=pars[1];
#                 ^
# ../bin/N4arbfi.cpp:83:17: warning: unused variable 'f8' [-Wunused-variable]
#     long double f8=pars[7];
#                 ^
# ../bin/N4arbfi.cpp:89:17: warning: unused variable 'f14' [-Wunused-variable]
#     long double f14=pars[13];
#                 ^
# ../bin/N4arbfi.cpp:76:17: warning: unused variable 'f1' [-Wunused-variable]
#     long double f1=pars[0];
#                 ^
# ../bin/N4arbfi.cpp:82:17: warning: unused variable 'f7' [-Wunused-variable]
#     long double f7=pars[6];
#                 ^
# ../bin/N4arbfi.cpp:88:17: warning: unused variable 'f13' [-Wunused-variable]
#     long double f13=pars[12];
#                 ^
# ../bin/N4arbfi.cpp:90:17: warning: unused variable 'f15' [-Wunused-variable]
#     long double f15=pars[14];
#                 ^
# ../bin/N4arbfi.cpp:81:17: warning: unused variable 'f6' [-Wunused-variable]
#     long double f6=pars[5];
#                 ^
# ../bin/N4arbfi.cpp:87:17: warning: unused variable 'f12' [-Wunused-variable]
#     long double f12=pars[11];
#                 ^
# ../bin/N4arbfi.cpp:91:17: warning: unused variable 'f16' [-Wunused-variable]
#     long double f16=pars[15];
#                 ^
# ../bin/N4arbfi.cpp:80:17: warning: unused variable 'f5' [-Wunused-variable]
#     long double f5=pars[4];
#                 ^
# ../bin/N4arbfi.cpp:86:17: warning: unused variable 'f11' [-Wunused-variable]
#     long double f11=pars[10];
#                 ^
# In file included from ../bin/N4arbfi.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:512:11: warning: unused variable 'mincritpoint' [-Wunused-variable]
#         T mincritpoint;
#           ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/N4arbfi.cpp:158:91: note: in instantiation of member function 'GRFCalculations<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &N4arbfi_GRFCalculations<long double,mpc_50,polytype_50,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                           ^
# In file included from ../bin/N4arbfi.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:513:22: warning: unused variable 'thirdderx0' [-Wunused-variable]
#         T thirdderx, thirdderx0;
#                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:217:83: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type nnum, nden, degreenum, degreeden, degreesum, i, j;
#                                                                                   ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:403:5: note: in instantiation of function template specialization 'get_fraction_derivative_coeffs<long double>' requested here
#     get_fraction_derivative_coeffs<T>(num,den,derivativenum,derivativeden);
#     ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/N4arbfi.cpp:158:91: note: in instantiation of member function 'GRFCalculations<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &N4arbfi_GRFCalculations<long double,mpc_50,polytype_50,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                           ^
# In file included from ../bin/N4arbfi.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:665:38: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type i, j, nnum, nden;
#                                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:169:20: note: in instantiation of function template specialization 'compute_monotonic<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#             result=compute_monotonic<T,Tpolyc,polytype,thresholdtype>(num,den,thresholdimag); //return {-1} if derivative is 0, {-2} if no roots for the derivative of the GRF, -3 for each root out of the 10^-15,10^15 range, and the roots otherwise
#                    ^
# ../bin/N4arbfi.cpp:160:98: note: in instantiation of member function 'GRFCalculations<long double, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfacemonotonic' requested here
#     .def("interfacemonotonic", &N4arbfi_GRFCalculations<long double,mpc_50,polytype_50,mpfr_15>::interfacemonotonic, py::arg("thresholdimag")=1e-15)
#                                                                                                  ^
# In file included from ../bin/N4arbfi.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:217:83: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type nnum, nden, degreenum, degreeden, degreesum, i, j;
#                                                                                   ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:403:5: note: in instantiation of function template specialization 'get_fraction_derivative_coeffs<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#     get_fraction_derivative_coeffs<T>(num,den,derivativenum,derivativeden);
#     ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/N4arbfi.cpp:169:87: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &N4arbfi_GRFCalculations<mpfr_50,mpc_50,polytype_50,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                       ^
# In file included from ../bin/N4arbfi.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:665:38: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type i, j, nnum, nden;
#                                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:169:20: note: in instantiation of function template specialization 'compute_monotonic<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#             result=compute_monotonic<T,Tpolyc,polytype,thresholdtype>(num,den,thresholdimag); //return {-1} if derivative is 0, {-2} if no roots for the derivative of the GRF, -3 for each root out of the 10^-15,10^15 range, and the roots otherwise
#                    ^
# ../bin/N4arbfi.cpp:171:94: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<50, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<50>, boost::multiprecision::et_on>, Polynomial<50>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfacemonotonic' requested here
#     .def("interfacemonotonic", &N4arbfi_GRFCalculations<mpfr_50,mpc_50,polytype_50,mpfr_15>::interfacemonotonic, py::arg("thresholdimag")=1e-15)
#                                                                                              ^
# In file included from ../bin/N4arbfi.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:217:83: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type nnum, nden, degreenum, degreeden, degreesum, i, j;
#                                                                                   ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:403:5: note: in instantiation of function template specialization 'get_fraction_derivative_coeffs<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#     get_fraction_derivative_coeffs<T>(num,den,derivativenum,derivativeden);
#     ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:151:24: note: in instantiation of function template specialization 'compute_pos_stp<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#                 result=compute_pos_stp<T,Tpolyc,polytype,thresholdtype>(num,den,"aberth",verbose,midpoint,thresholdimag,writex05coeffs, absder, normalisefirst,fnamecoeffs);
#                        ^
# ../bin/N4arbfi.cpp:180:90: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfaceps' requested here
#     .def("interfaceps", &N4arbfi_GRFCalculations<mpfr_100,mpc_100,polytype_100,mpfr_15>::interfaceps,py::arg("verbose")=false, py::arg("thresholdimag")=1e-15,py::arg("minx0")=false,py::arg("maxx1")=false,py::arg("writex05coeffs")=false, py::arg("absder")=false, py::arg("normalisefirst")=true, py::arg("fnamecoeffs")="coefficients.txt")
#                                                                                          ^
# In file included from ../bin/N4arbfi.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:11:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/posstpfunc_cpp_boost_multiprT.hpp:665:38: warning: unused variable 'j' [-Wunused-variable]
#     typename vector<T>::size_type i, j, nnum, nden;
#                                      ^
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:169:20: note: in instantiation of function template specialization 'compute_monotonic<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>' requested here
#             result=compute_monotonic<T,Tpolyc,polytype,thresholdtype>(num,den,thresholdimag); //return {-1} if derivative is 0, {-2} if no roots for the derivative of the GRF, -3 for each root out of the 10^-15,10^15 range, and the roots otherwise
#                    ^
# ../bin/N4arbfi.cpp:182:97: note: in instantiation of member function 'GRFCalculations<boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<100, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>, boost::multiprecision::number<boost::multiprecision::backends::mpc_complex_backend<100>, boost::multiprecision::et_on>, Polynomial<100>, boost::multiprecision::number<boost::multiprecision::backends::mpfr_float_backend<15, boost::multiprecision::allocate_dynamic>, boost::multiprecision::et_on>>::interfacemonotonic' requested here
#     .def("interfacemonotonic", &N4arbfi_GRFCalculations<mpfr_100,mpc_100,polytype_100,mpfr_15>::interfacemonotonic, py::arg("thresholdimag")=1e-15)
#                                                                                                 ^
# In file included from ../bin/N4arbfi.cpp:1:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/commonincludes.hpp:3:
# In file included from /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared/utilsGRF/GRFCalculations.hpp:10:
# /Users/rosamartinezcorral/Dropbox (HMS)/work2/shared_fromothers/polynomials_multiprecision/polynomials/include/polynomial/polynomial.hpp:1122:52: warning: unused typedef 'RTM' [-Wunused-local-typedef]
#             typedef number<mpfr_float_backend<M> > RTM;
#                                                    ^
# 28 warnings generated.
